# %% [markdown]
# <a href="https://colab.research.google.com/github/MicaelaRomeroC3/sotto/blob/main/Sotto_PuntoEntrenamiento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Ejecutar para SERVICIO TELÉFONICO**

# %%
import pandas as pd

# Ruta del archivo Excel en tu Google Drive
file_path = '/content/drive/MyDrive/Sottotempo/Exportación evaluaciones con Puntos de Entrenamiento.xlsx'

# Cargar el archivo Excel
df = pd.read_excel(file_path)

df.head()
# Out:
#                                     ID  \
# 0  101S_1070-OP_11_100_20250401H_09_35
# 1  101S_1070-OP_11_100_20250401H_09_36
# 2  101S_1070-OP_11_100_20250401H_09_37
# 3  101S_1070-OP_11_100_20250401H_09_38
# 4  101S_1070-OP_11_100_20250401H_09_39
#
#                                   IDEVENTCLIENTE EQUIPO CIP  ID SERVICIO  \
# 0  Llamada1-3dcc58bc-aec8-47fb-9781-e2038b2b8087                    1070
# 1  Llamada1-8b42007d-1d18-4e0b-914e-100a29e43506                    1070
# 2  Llamada1-87bf3b0b-4505-4b86-b97e-b396475574ff                    1070
# 3  Llamada1-95c3b802-e712-4c0f-a60f-751f66809d21                    1070
# 4  Llamada1-97dea923-c2ce-403a-b67c-e17076e7cf3c                    1070
#
#                    SERVICIO          EMPRESA DISPOSITIVO  MEDIDOR  \
# 0  Decathlon Adhoc Teléfono  Decathlon Adhoc                10057
# 1  Decathlon Adhoc Teléfono  Decathlon Adhoc                10057
# 2  Decathlon Adhoc Teléfono  Decathlon Adhoc                10057
# ...

# %% [markdown]
# **Se pasan las columnas a nombres simplificados para realizar el recuento de penalizaciones y se eliminan columnas que no sirven**

# %%
# Diccionario de mapeo de códigos a descripciones
codigo_a_texto = {
    "C1. TIEMPO DE RESPUESTA": "C1",
    "C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MENOS DE 5 TONOS HASTA SER ATENDIDOS.": "subgrupo_C1_2",
    "C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MENOS DE 20 SEGUNDOS HASTA SER ATENDIDOS.": "subgrupo_C1_3",
    "C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MÁS DE 5 TONOS HASTA SER ATENDIDOS.": "subgrupo_C1_4",
    "C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MÁS DE 20 SEGUNDOS HASTA SER ATENDIDOS.": "subgrupo_C1_5",
    "C2. ACCEDER AL SERVICIO DESEADO": "C2",
    "C1. TIEMPO DE RESPUESTA.COND.LA LLAMADA NO HA SIDO ATENDIDA TRAS PASARSE EL PLAZO DE 4 MINUTOS DE ESPERA Y NO SER ATENDIDOS POR UN ASESOR.": "subgrupo_C1_6",
    "C2. ACCEDER AL SERVICIO DESEADO.COND.EL MENSAJE DEL IVR TIENE UNA DURACIÓN INFERIOR AL MINUTO.": "subgrupo_C2_1",
    "C2. ACCEDER AL SERVICIO DESEADO.COND.EL MENSAJE DEL IVR TIENE UNA DURACIÓN SUPERIOR AL MINUTO.": "subgrupo_C2_2",
    "C2. ACCEDER AL SERVICIO DESEADO.OBS": "subgrupo_C2_3",
    "C3. CONTACTAR/HABLAR CON UN ASESOR": "C3",
    "C3. CONTACTAR/HABLAR CON UN ASESOR.COND.TRANSCURRE MENOS DE 1 MINUTO HASTA QUE HABLAMOS CON UN ASESOR.": "subgrupo_C3_1",
    "C3. CONTACTAR/HABLAR CON UN ASESOR.COND.TRANSCURREN ENTRE 1 Y 2 MINUTOS HASTA QUE HABLAMOS CON UN ASESOR.": "subgrupo_C3_2",
    "C3. CONTACTAR/HABLAR CON UN ASESOR.COND.TRANSCURREN ENTRE 2 Y 4 MINUTOS HASTA QUE HABLAMOS CON UN ASESOR.": "subgrupo_C3_3",
    "C3. CONTACTAR/HABLAR CON UN ASESOR.OBS": "subgrupo_C3_4",
    "C4. TIEMPO DE TRANSFERENCIA": "C4",
    "C4. TIEMPO DE TRANSFERENCIA.COND.EL ASESOR TRANSFIERE LA LLAMADA DEL CLIENTE EN UN TIEMPO INFERIOR A 30 SEGUNDOS.": "subgrupo_C4_1",
    "C4. TIEMPO DE TRANSFERENCIA.COND.EL ASESOR TRANSFIERE LA LLAMADA DEL CLIENTE EN UN TIEMPO ENTRE 30 Y 45 SEGUNDOS.": "subgrupo_C4_2",
    "C4. TIEMPO DE TRANSFERENCIA.COND.EL ASESOR/S TRANSFIERE LA LLAMADA DEL CLIENTE EN UN TIEMPO SUPERIOR A LOS 45 SEGUNDOS.": "subgrupo_C4_3",
    "C4. TIEMPO DE TRANSFERENCIA.OBS": "subgrupo_C4_4",
    "C5. LLAMADA EN ESPERA (TÚNEL)": "C5",
    "C5. LLAMADA EN ESPERA (TÚNEL).COND.SE PRODUCEN DOS ESPERAS INFERIORES A 30 SEGUNDOS CON PREVIO AVISO PARA LA MISMA CONSULTA.": "subgrupo_C5_1",
    "C5. LLAMADA EN ESPERA (TÚNEL).COND.SE PRODUCE UNA ESPERA INFERIOR A 30 SEGUNDOS CON PREVIO AVISO.": "subgrupo_C5_2",
    "C5. LLAMADA EN ESPERA (TÚNEL).COND.SE PRODUCE UNA ESPERA INFERIOR A 30 SEGUNDOS SIN PREVIO AVISO.": "subgrupo_C5_3",
    "C5. LLAMADA EN ESPERA (TÚNEL).COND.SE PRODUCE UNA ESPERA SUPERIOR A 30 SEGUNDOS.": "subgrupo_C5_4",
    "C5. LLAMADA EN ESPERA (TÚNEL).COND.SE PRODUCEN DOS ESPERAS PARA CONSULTAS DIFERENTES.": "subgrupo_C5_5",
    "C5. LLAMADA EN ESPERA (TÚNEL).COND.SE PRODUCEN DOS ESPERAS PARA LA MISMA CONSULTA SUPERIORES A 30 SEGUNDOS.": "subgrupo_C5_6",
    "C5. LLAMADA EN ESPERA (TÚNEL).OBS": "subgrupo_C5_7",
    "C6. TOMA DE CONTACTO": "C6",
    "C6. TOMA DE CONTACTO.COND.EL ASESOR SE IDENTIFICA CON SU NOMBRE, CON UNA VELOCIDAD DE DISCURSO Y ELOCUCIÓN ADECUADAS.": "subgrupo_C6_1",
    "C6. TOMA DE CONTACTO.COND.EL ASESOR MANTIENE UNA VELOCIDAD Y ELOCUCIÓN ADECUADAS, PERO NO SE IDENTIFICA CON SU NOMBRE.": "subgrupo_C6_2",
    "C6. TOMA DE CONTACTO.COND.EL ASESOR SE IDENTIFICA CON SU NOMBRE, PERO CON UNA VELOCIDAD Y ELOCUCIÓN POCO ADECUADAS.": "subgrupo_C6_3",
    "C6. TOMA DE CONTACTO.COND.EL ASESOR NI SE IDENTIFICA CON SU NOMBRE NI SU VELOCIDAD Y ELOCUCIÓN ES BUENA.": "subgrupo_C6_4",
    "C6. TOMA DE CONTACTO.OBS": "subgrupo_C6_5",
    "C7. IDENTIFICACIÓN": "C7",
    "C7. IDENTIFICACIÓN.COND.LA GRABACIÓN IVR SÍ IDENTIFICA A LA EMPRESA CON SU NOMBRE.": "subgrupo_C7_1",
    "C7. IDENTIFICACIÓN.COND.LA GRABACIÓN IVR NO IDENTIFICA A LA EMPRESA CON SU NOMBRE.": "subgrupo_C7_2",
    "C7. IDENTIFICACIÓN.OBS": "subgrupo_C7_3",
    "C8. PERSONALIZACIÓN": "C8",
    "C8. PERSONALIZACIÓN.COND.EL ASESOR PERSONALIZA LA CONVERSACIÓN CON EL NOMBRE DEL CLIENTE.": "subgrupo_C8_1",
    "C8. PERSONALIZACIÓN.COND.EL ASESOR VUELVE A PEDIR EL NOMBRE DEL CLIENTE CUANDO LO SABE Y LO HA UTILIZADO ANTES.": "subgrupo_C8_2",
    "C8. PERSONALIZACIÓN.COND.EL ASESOR SE EQUIVOCA CON EL NOMBRE DEL CLIENTE.": "subgrupo_C8_3",
    "C8. PERSONALIZACIÓN.COND.EL ASESOR NO PERSONALIZA LA CONVERSACIÓN EN NINGÚN MOMENTO DE ESTA.": "subgrupo_C8_4",
    "C8. PERSONALIZACIÓN.OBS": "subgrupo_C8_5",
    "C9. MOTIVO DE CONTACTO": "C9",
    "C9. MOTIVO DE CONTACTO.COND.EL ASESOR REALIZA EL SONDEO NECESARIO PARA IDENTIFICAR LA NECESIDAD DEL CLIENTE.": "subgrupo_C9_1",
    "C9. MOTIVO DE CONTACTO.COND.EL ASESOR NO REALIZA EL SONDEO NECESARIO PARA IDENTIFICAR LA NECESIDAD DEL CLIENTE.": "subgrupo_C9_2",
    "C9. MOTIVO DE CONTACTO.OBS": "subgrupo_C9_3",
    "C10. REFORMULACIÓN": "C10",
    "C10. REFORMULACIÓN.COND.EL ASESOR UTILIZA LA CONSULTA DEL CLIENTE PARA RESPONDER A ELLA.": "subgrupo_C10_1",
    "C10. REFORMULACIÓN.COND.EL ASESOR REFORMULA LA CONSULTA DEL CLIENTE PARA RESPONDER A ELLA.": "subgrupo_C10_2",
    "C10. REFORMULACIÓN.COND.EL ASESOR RESPONDE DIRECTAMENTE A LA PETICIÓN SIN HABER UTILIZADO LA CONSULTA DEL CLIENTE.": "subgrupo_C10_3",
    "C10. REFORMULACIÓN.COND.EL ASESOR RESPONDE DIRECTAMENTE A LA PETICIÓN SIN HABER REFORMULADO LA CONSULTA DEL CLIENTE.": "subgrupo_C10_4",
    "C10. REFORMULACIÓN.OBS": "subgrupo_C10_5",
    "C11. DIRECCIÓN DE LA LLAMADA": "C11",
    "C11. DIRECCIÓN DE LA LLAMADA.COND.DIRIGE LA SECUENCIA DE LLAMADA MANTENIENDO EL ENFOQUE.": "subgrupo_C11_1",
    "C11. DIRECCIÓN DE LA LLAMADA.COND.NO ALARGA NI PRECIPITA DE MANERA INNECESARIA EL CIERRE DE CONVERSACIÓN.": "subgrupo_C11_2",
    "C11. DIRECCIÓN DE LA LLAMADA.COND.NO DIRIGE LA SECUENCIA DE LLAMADA MANTENIENDO EL ENFOQUE.": "subgrupo_C11_3",
    "C11. DIRECCIÓN DE LA LLAMADA.COND.ALARGA O PRECIPITA DE MANERA INNECESARIA EL CIERRE DE CONVERSACIÓN.": "subgrupo_C11_4",
    "C11. DIRECCIÓN DE LA LLAMADA.OBS": "subgrupo_C11_5",
    "C12. TRANSFERENCIA SIN FRICCIÓN": "C12",
    "C12. TRANSFERENCIA SIN FRICCIÓN.COND.EL CLIENTE NO TIENE QUE VOLVER A EXPLICAR LA CONSULTA AL ASESOR AL QUE SE HA TRANSFERIDO.": "subgrupo_C12_1",
    "C12. TRANSFERENCIA SIN FRICCIÓN.COND.EL CLIENTE EXPLICA PARCIALMENTE LA CONSULTA AL ASESOR AL QUE SE HA TRANSFERIDO.": "subgrupo_C12_2",
    "C12. TRANSFERENCIA SIN FRICCIÓN.COND.EL CLIENTE TIENE QUE VOLVER A EXPLICAR DE NUEVO LA CONSULTA AL ASESOR AL QUE SE HA TRANSFERIDO.": "subgrupo_C12_3",
    "C12. TRANSFERENCIA SIN FRICCIÓN.OBS": "subgrupo_C12_4",
    "C13. SABER ORIENTAR": "C13",
    "C13. SABER ORIENTAR.COND.EL PRIMER ASESOR CONSIGUE TRANSFERIR LA LLAMADA DEL CLIENTE AL ASESOR ADECUADO A LA PRIMERA.": "subgrupo_C13_1",
    "C13. SABER ORIENTAR.COND.EL PRIMER ASESOR NO CONSIGUE TRANSFERIR LA LLAMADA DEL CLIENTE AL ASESOR ADECUADO A LA PRIMERA, TENIENDO QUE VOLVER A TRANSFERIR LA LLAMADA.": "subgrupo_C13_2",
    "C13. SABER ORIENTAR.OBS": "subgrupo_C13_3",
    "C14. SABER ESCUCHAR/ESCUCHA ACTIVA": "C14",
    "C14. SABER ESCUCHAR/ESCUCHA ACTIVA.COND.EL ASESOR NO HA INTERRUMPIDO AL CLIENTE EN NINGÚN MOMENTO DE LA LLAMADA.": "subgrupo_C14_1",
    "C14. SABER ESCUCHAR/ESCUCHA ACTIVA.COND.EL ASESOR HA INTERRUMPIDO AL CLIENTE EN ALGÚN MOMENTO DE LA LLAMADA, PERO SE HA DISCULPADO POR ELLO.": "subgrupo_C14_2",
    "C14. SABER ESCUCHAR/ESCUCHA ACTIVA.COND.EL ASESOR INTERRUMPE AL CLIENTE EN DIFERENTES MOMENTOS DE LA LLAMADA, SIN DISCULPARSE POR ELLO.": "subgrupo_C14_3",
    "C14. SABER ESCUCHAR/ESCUCHA ACTIVA.OBS": "subgrupo_C14_4",
    "C15. SABER DECIR (CAPACIDAD EXPRESIÓN)": "C15",
    "C15. SABER DECIR (CAPACIDAD EXPRESIÓN).COND.EL ASESOR UTILIZA UN DISCURSO ADAPTADO A LA CONSULTA DEL CLIENTE, SIN TÉRMINOS INCOMPRENSIBLES.": "subgrupo_C15_1",
    "C15. SABER DECIR (CAPACIDAD EXPRESIÓN).COND.EL ASESOR UTILIZA EN SU DISCURSO ALGUNOS TECNICISMOS O PALABRAS CLAVE, LAS CUÁLES NO EXPLICA SU SIGNIFICADO PARA FACILITAR LA COMPRENSIÓN DEL CLIENTE.": "subgrupo_C15_2",
    "C15. SABER DECIR (CAPACIDAD EXPRESIÓN).COND.EL ASESOR UTILIZA UN DISCURSO PLAGADO DE TECNICISMOS Y SIGLAS INCOMPRENSIBLES, POCO ENTENDIBLES PARA EL CLIENTE.": "subgrupo_C15_3",
    "C15. SABER DECIR (CAPACIDAD EXPRESIÓN).OBS": "subgrupo_C15_4",
    "C16. CALIDAD DEL TONO": "C16",
    "C16. CALIDAD DEL TONO.COND.EL ASESOR MANTIENE UN TONO Y DISCURSO ADECUADO DURANTE TODA LA LLAMADA.": "subgrupo_C16_1",
    "C16. CALIDAD DEL TONO.COND.DISCURSO ROBOTIZADO.": "subgrupo_C16_2",
    "C16. CALIDAD DEL TONO.COND.EL ASESOR ATIENDE CON PRISA, PROCURA FINALIZAR LA LLAMADA.": "subgrupo_C16_3",
    "C16. CALIDAD DEL TONO.COND.TONO FRIO Y DISTANTE. AUSENCIA DE CONTACTO EMOCIONAL.": "subgrupo_C16_4",
    "C16. CALIDAD DEL TONO.COND.EN ALGÚN MOMENTO DE LA LLAMADA NO SE ENTIENDE AL ASESOR.": "subgrupo_C16_5",
    "C16. CALIDAD DEL TONO.COND.EL ASESOR UTILIZA IRONÍA O SARCASMO.": "subgrupo_C16_6",
    "C16. CALIDAD DEL TONO.COND.EL ASESOR SE MUESTRA POCO CORDIAL AUNQUE EDUCADO.": "subgrupo_C16_7",
    "C16. CALIDAD DEL TONO.COND.EL ASESOR NO ENTREGA RESPUESTA. DEMASIADO INSISTENTE EN LLAMAR EN UN MOMENTO POSTERIOR.": "subgrupo_C16_8",
    "C16. CALIDAD DEL TONO.COND.A PESAR QUE LA ATENCIÓN ES CORRECTA Y SE RESUELVE LA CONSULTA, EL ASESOR TRANSMITE POCO DINAMISMO EN LA LLAMADA. TONO MONÓTONO.": "subgrupo_C16_9",
    "C16. CALIDAD DEL TONO.COND.TONO POCO AMABLE, NADA EMPÁTICO CON EL CLIENTE.": "subgrupo_C16_10",
    "C16. CALIDAD DEL TONO.OBS": "subgrupo_C16_11",
    "C17. IMPRESIÓN GENERAL": "C17",
    "C17. IMPRESIÓN GENERAL.COND.EL ASESOR DEMUESTRA SEGURIDAD DURANTE LA LLAMADA, OFRECIENDO EXPLICACIONES CLARAS.": "subgrupo_C17_1",
    "C17. IMPRESIÓN GENERAL.COND.EL ASESOR DEMUESTRA EDUCACIÓN AL ATENDER LA LLAMADA CON AMABILIDAD Y CORDIALIDAD.": "subgrupo_C17_2",
    "C17. IMPRESIÓN GENERAL.COND.EL ASESOR NO DEMUESTRA SEGURIDAD DURANTE LA LLAMADA, DUDANDO O TITUBEANDO EN DIFERENTES MOMENTOS DE ESTA.": "subgrupo_C17_3",
    "C17. IMPRESIÓN GENERAL.COND.EL ASESOR NO DEMUESTRA EDUCACIÓN AL ATENDER LA LLAMADA CON POCA AMABILIDAD.": "subgrupo_C17_4",
    "C17. IMPRESIÓN GENERAL.COND.LA LLAMADA NO HA SIDO ATENDIDA TRAS PASARSE EL PLAZO DE 4 MINUTOS DE ESPERA Y NO SER ATENDIDOS POR UN ASESOR.": "subgrupo_C17_5",
    "C17. IMPRESIÓN GENERAL.OBS": "subgrupo_C17_6",
    "C18. CALIDAD DEL ENTORNO": "C18",
    "C18. CALIDAD DEL ENTORNO.COND.NO SE DETECTAN INTERFERENCIAS O MICROCORTES DURANTE EL TRANSCURSO DE LA CONVERSACIÓN.": "subgrupo_C18_1",
    "C18. CALIDAD DEL ENTORNO.COND.NO SE DETECTA RUIDO AMBIENTAL DURANTE EL TRANSCURSO DE LA CONVERSACIÓN.": "subgrupo_C18_2",
    "C18. CALIDAD DEL ENTORNO.COND.SE DETECTAN INTERFERENCIAS O MICROCORTES DURANTE EL TRANSCURSO DE LA CONVERSACIÓN.": "subgrupo_C18_3",
    "C18. CALIDAD DEL ENTORNO.COND.SE DETECTA RUIDO AMBIENTAL DURANTE EL TRANSCURSO DE LA CONVERSACIÓN.": "subgrupo_C18_4",
    "C18. CALIDAD DEL ENTORNO.OBS": "subgrupo_C18_5",
    "C19. CALIDAD DE LA RESPUESTA": "C19",
    "C19. CALIDAD DE LA RESPUESTA.COND.EL ASESOR OFRECE UNA RESPUESTA ADECUADA A LA CONSULTA DEL CLIENTE. MUESTRA CONOCIMIENTO (ENTENDIMIENTO) DE LA CONSULTA O PRODUCTO.": "subgrupo_C19_1",
    "C19. CALIDAD DE LA RESPUESTA.COND.EL ASESOR OFRECE UNA RESPUESTA ORIENTATIVA, Y SE INDICA QUE LLAME A OTRO NÚMERO/SUCURSAL/WEB PARA TENER LA INFORMACIÓN. MUESTRA CONOCIMIENTO NO ASENTADO (ENTENDIMIENTO) DE LA CONSULTA O PRODUCTO.": "subgrupo_C19_2",
    "C19. CALIDAD DE LA RESPUESTA.COND.EL ASESOR ENVÍA LA RESPUESTA POR CORREO. EN OTRAS OCASIONES SE HA RESPONDIDO A LA CONSULTA DIRECTAMENTE, SIN NECESIDAD DE OBTENERLA POR OTRA VÍA.": "subgrupo_C19_3",
    "C19. CALIDAD DE LA RESPUESTA.COND.EL ASESOR NO OFRECE UNA RESPUESTA COMPLETA. EN OTRAS OCASIONES SE HA OFRECIDO UNA INFORMACIÓN COMPLETA. NO APORTA INFORMACIÓN NECESARIA PARA QUE EL CLIENTE LO ENTIENDA PERFECTAMENTE.": "subgrupo_C19_4",
    "C19. CALIDAD DE LA RESPUESTA.COND.NO SE OFRECE UNA RESPUESTA COMPLETA, SINO QUE SE REQUIERE QUE DEMOS NUESTROS DATOS. EN OTRAS OCASIONES SE HA OFRECIDO UNA INFORMACIÓN SIN REQUERIR APORTAR DATOS.": "subgrupo_C19_5",
    "C19. CALIDAD DE LA RESPUESTA.COND.EL ASESOR NO SE CENTRA EN OFRECER LA RESPUESTA SOLICITADA POR EL CLIENTE. APORTA INFORMACIÓN POCO INFLUYENTE PARA LA CONSULTA.": "subgrupo_C19_6",
    "C19. CALIDAD DE LA RESPUESTA.COND.LA RESPUESTA NO ES COMPLETA, AL INTENTAR TRANSFERIR EL ASESOR LA LLAMADA AL DEPARTAMENTO CORRESPONDIENTE SIN ÉXITO AL ESTAR FUERA DEL HORARIO DE ATENCIÓN.": "subgrupo_C19_7",
    "C19. CALIDAD DE LA RESPUESTA.COND.LA RESPUESTA NO ES COMPLETA, AL INTENTAR EL ASESOR CONSEGUIR LA INFORMACIÓN POR OTRA VÍA Y NO CONSEGUIRLO (NO LE COGEN EL TELÉFONO, LA LÍNEA ESTÁ OCUPADA O ALGUIEN ESTÁ OCUPADO PARA HACER LA CONSULTA).": "subgrupo_C19_8",
    "C19. CALIDAD DE LA RESPUESTA.COND.LA RESPUESTA ES ESCUETA. CONTESTA CON MONOSÍLABOS: NO EXPLICA NI DA OPCIONES A LA PREGUNTA SOLICITADA.": "subgrupo_C19_9",
    "C19. CALIDAD DE LA RESPUESTA.COND.RESPUESTA NO ADECUADA, DIFERENTE A LA CONSULTA. FALTA DE ESCUCHA ACTIVA. O FALTA DE CONOCIMIENTO (ENTENDIMIENTO) DE LA CONSULTA O PRODUCTO.": "subgrupo_C19_10",
    "C19. CALIDAD DE LA RESPUESTA.COND.EL ASESOR NO OFRECE UNA RESPUESTA, SINO QUE SE INDICA OTRO NÚMERO AL QUE LLAMAR/MAIL QUE ENVIAR/WEB QUE VISITAR/RED SOCIAL A CONSULTAR/CHAT AL QUE HABLAR.": "subgrupo_C19_11",
    "C19. CALIDAD DE LA RESPUESTA.COND.LA LLAMADA NO HA SIDO ATENDIDA TRAS PASARSE EL PLAZO DE 4 MINUTOS DE ESPERA Y NO SER ATENDIDOS POR UN ASESOR.": "subgrupo_C19_12",
    "C19. CALIDAD DE LA RESPUESTA.OBS": "subgrupo_C19_13",
    "C20. PROACTIVIDAD": "C20",
    "C20. PROACTIVIDAD.COND.INFORMACIÓN ÚTIL, QUE APORTA VALOR AL CLIENTE.": "subgrupo_C20_1",
    "C20. PROACTIVIDAD.COND.ADAPTA LOS PROCESOS EN LA MEDIDA DE LO POSIBLE Y OFRECE ALTERNATIVAS.": "subgrupo_C20_2",
    "C20. PROACTIVIDAD.COND.TOMA DECISIONES EFICIENTES Y EFICACES PARA RESOLVER LA LLAMADA.": "subgrupo_C20_3",
    "C20. PROACTIVIDAD.COND.EXCESO DE INFORMACIÓN NO ÚTIL, QUE NO APORTA VALOR AL CLIENTE.": "subgrupo_C20_4",
    "C20. PROACTIVIDAD.COND.NO ADAPTA LOS PROCESOS EN LA MEDIDA DE LO POSIBLE Y SÓLO OFRECE ALTERNATIVAS POR INSISTENCIA DEL CLIENTE.": "subgrupo_C20_5",
    "C20. PROACTIVIDAD.COND.NO TOMA DECISIONES EFICIENTES Y EFICACES PARA RESOLVER LA LLAMADA.": "subgrupo_C20_6",
    "C20. PROACTIVIDAD.OBS": "subgrupo_C20_7",
    "C21. SOLUCIÓN AL PRIMER CONTACTO (FCR)": "C21",
    "C21. SOLUCIÓN AL PRIMER CONTACTO (FCR).COND.SE SOLUCIONA LA CONSULTA EN EL PRIMER CONTACTO Y NO ES NECESARIO REALIZAR UN CONTACTO POSTERIOR.": "subgrupo_C21_1",
    "C21. SOLUCIÓN AL PRIMER CONTACTO (FCR).COND.NO SE SOLUCIONA LA CONSULTA EN EL PRIMER CONTACTO Y ES NECESARIO REALIZAR UN CONTACTO POSTERIOR.": "subgrupo_C21_2",
    "C21. SOLUCIÓN AL PRIMER CONTACTO (FCR).OBS": "subgrupo_C21_3",
    "C22. IMAGEN CORPORATIVA": "C22",
    "C22. IMAGEN CORPORATIVA.COND.LA PROFESIONALIDAD DEL GESTOR TRASLADA UNA IMAGEN POSITIVA.": "subgrupo_C22_1",
    "C22. IMAGEN CORPORATIVA.COND.SE DISCULPA ANTE LAS MOLESTIAS EVIDENCIADAS POR EL CLIENTE DURANTE LA LLAMADA.": "subgrupo_C22_2",
    "C22. IMAGEN CORPORATIVA.COND.LA FALTA DE PROFESIONALIDAD DEL GESTOR TRASLADA UNA IMAGEN NEGATIVA.": "subgrupo_C22_3",
    "C22. IMAGEN CORPORATIVA.COND.NO SE DISCULPA ANTE LAS MOLESTIAS EVIDENCIADAS POR EL CLIENTE DURANTE LA LLAMADA.": "subgrupo_C22_4",
    "C22. IMAGEN CORPORATIVA.OBS": "subgrupo_C22_5",
    "C23. DESPEDIDA": "C23",
    "C23. DESPEDIDA.COND.EL ASESOR SE DESPIDE DEL CLIENTE CON SU NOMBRE, HABIÉNDOSE ASEGURADO DE QUE TODAS SUS DUDAS ESTÉN RESUELTAS.": "subgrupo_C23_1",
    "C23. DESPEDIDA.COND.EL ASESOR SE DESPIDE DEL CLIENTE CON SU NOMBRE, PERO NO SE ASEGURA QUE LE QUEDEN DUDAS POR RESOLVER.": "subgrupo_C23_2",
    "C23. DESPEDIDA.COND.EL ASESOR SE ASEGURA QUE TODAS LAS DUDAS DEL CLIENTE ESTÉN RESUELTAS, PERO NO UTILIZA EL NOMBRE DE ESTE EN LA DESPEDIDA.": "subgrupo_C23_3",
    "C23. DESPEDIDA.COND.EL ASESOR NI SE DESPIDE DEL CLIENTE CON SU NOMBRE NI SE ASEGURA QUE LE QUEDEN DUDAS POR RESOLVER.": "subgrupo_C23_4",
    "C23. DESPEDIDA.COND.NO HA HABIDO DESPEDIDA AL NO HABERSE TRANSFERIDO LA LLAMADA.": "subgrupo_C23_5",
    "C23. DESPEDIDA.COND.NO HA HABIDO DESPEDIDA AL CORTARSE LA TRANSFERENCIA.": "subgrupo_C23_6",
    "C23. DESPEDIDA.OBS": "subgrupo_C23_7"
}

# Filtrar solo las columnas que están en el diccionario
columnas_validas = [col for col in df.columns if col in codigo_a_texto]

# Subset del DataFrame con esas columnas
df = df[columnas_validas]

# Renombrar las columnas según el diccionario
df.rename(columns=codigo_a_texto, inplace=True)

# Mostrar los primeros resultados para verificar
print(df.columns.tolist())
print(len(df.columns))

df.head()
# Out:
# ['C1', 'subgrupo_C1_2', 'subgrupo_C1_3', 'subgrupo_C1_4', 'subgrupo_C1_5', 'subgrupo_C1_6', 'C2', 'subgrupo_C2_1', 'subgrupo_C2_2', 'subgrupo_C2_3', 'C3', 'subgrupo_C3_1', 'subgrupo_C3_2', 'subgrupo_C3_3', 'subgrupo_C3_4', 'C4', 'subgrupo_C4_1', 'subgrupo_C4_2', 'subgrupo_C4_3', 'subgrupo_C4_4', 'C5', 'subgrupo_C5_1', 'subgrupo_C5_2', 'subgrupo_C5_3', 'subgrupo_C5_4', 'subgrupo_C5_5', 'subgrupo_C5_6', 'subgrupo_C5_7', 'C6', 'subgrupo_C6_1', 'subgrupo_C6_2', 'subgrupo_C6_3', 'subgrupo_C6_4', 'subgrupo_C6_5', 'C7', 'subgrupo_C7_1', 'subgrupo_C7_2', 'subgrupo_C7_3', 'C8', 'subgrupo_C8_1', 'subgrupo_C8_2', 'subgrupo_C8_3', 'subgrupo_C8_4', 'subgrupo_C8_5', 'C9', 'subgrupo_C9_1', 'subgrupo_C9_2', 'subgrupo_C9_3', 'C10', 'subgrupo_C10_1', 'subgrupo_C10_2', 'subgrupo_C10_3', 'subgrupo_C10_4', 'subgrupo_C10_5', 'C11', 'subgrupo_C11_1', 'subgrupo_C11_2', 'subgrupo_C11_3', 'subgrupo_C11_4', 'subgrupo_C11_5', 'C12', 'subgrupo_C12_1', 'subgrupo_C12_2', 'subgrupo_C12_3', 'subgrupo_C12_4', 'C13', 
# ...

# %% [markdown]
# Recuento de penalizaciones

# %%
# Diccionario para almacenar los resultados
resultados = {}

# Columnas principales a analizar
columnas = [f'C{i}' for i in range(1, 24)]  # C1 a C23

# Recorremos todas las columnas
for columna in columnas:
    if columna in df.columns:
        # Buscar subgrupos relacionados con esta columna
        subgrupos = [col for col in df.columns if col.startswith(f'subgrupo_{columna}')]

        for subgrupo in subgrupos:
            # Filtrar solo filas donde la variable principal es 0 o 1
            filas_validas = df[(df[columna] == 0) | (df[columna] == 1)]

            # Contar los 1 en el subgrupo
            cuenta_1 = (filas_validas[subgrupo] == 1).sum()

            # Guardar el resultado (una única vez por subgrupo)
            resultados[subgrupo] = cuenta_1

# Convertimos directamente el diccionario a un DataFrame
resultados_df = pd.DataFrame(list(resultados.items()), columns=['Subgrupo', 'Penalizaciones'])


# Mostramos el DataFrame
print(resultados_df)
# Out:
#           Subgrupo  Penalizaciones
# 0    subgrupo_C1_2               0
# 1    subgrupo_C1_3               0
# 2    subgrupo_C1_4               0
# 3    subgrupo_C1_5               0
# 4    subgrupo_C1_6               0
# ..             ...             ...
# 116  subgrupo_C8_4              94
# 117  subgrupo_C8_5               0
# 118  subgrupo_C9_1               0
# 119  subgrupo_C9_2               0
# 120  subgrupo_C9_3               0
#
# [121 rows x 2 columns]

# %% [markdown]
# **TELÉFONO obtener penalizaciones de columna con puntuación máxima de 4**

# %%
subgrupos_c19 = [col for col in df.columns if col.startswith('subgrupo_C19')]

penalizaciones_c19 = {}

if 'C19' in df.columns:
    filas_c19 = df[(df['C19'] == 0) | (df['C19'] == 2)]

    for subgrupo in subgrupos_c19:
        cuenta = (filas_c19[subgrupo] == 1).sum()
        penalizaciones_c19[subgrupo] = cuenta

penalizaciones_c19_telefono = pd.DataFrame(
    list(penalizaciones_c19.items()),
    columns=['Subgrupo_C19', 'Penalizaciones_C19']
)

print(penalizaciones_c19_telefono)
# Out:
#        Subgrupo_C19  Penalizaciones_C19
# 0    subgrupo_C19_1                   0
# 1    subgrupo_C19_2                   0
# 2    subgrupo_C19_3                   0
# 3    subgrupo_C19_4                   0
# 4    subgrupo_C19_5                   0
# 5    subgrupo_C19_6                   0
# 6    subgrupo_C19_7                   0
# 7    subgrupo_C19_8                   0
# 8    subgrupo_C19_9                   0
# 9   subgrupo_C19_10                   0
# 10  subgrupo_C19_11                   0
# 11  subgrupo_C19_12                   0
# 12  subgrupo_C19_13                   0

# %% [markdown]
# **Se combinan ambos recuentos realizados**

# %%
# Convertimos los DataFrames a diccionarios para combinar fácilmente
penalizaciones_generales = dict(resultados_df.values)
penalizaciones_especiales = dict(penalizaciones_c19_telefono.values)

# Actualizamos los valores generales con los valores especiales para los subgrupos C19
penalizaciones_generales.update(penalizaciones_especiales)

# Creamos el DataFrame final combinado
resultado_final = pd.DataFrame(
    list(penalizaciones_generales.items()),
    columns=['Subgrupo', 'Penalizaciones']
)

# Mostramos el resultado
resultado_final
# Out:
#           Subgrupo  Penalizaciones
# 0    subgrupo_C1_2               0
# 1    subgrupo_C1_3               0
# 2    subgrupo_C1_4               0
# 3    subgrupo_C1_5               0
# 4    subgrupo_C1_6               0
# ..             ...             ...
# 116  subgrupo_C8_4              94
# 117  subgrupo_C8_5               0
# 118  subgrupo_C9_1               0
# 119  subgrupo_C9_2               0
# 120  subgrupo_C9_3               0
#
# [121 rows x 2 columns]

# %% [markdown]
# **Se pasa de nombre reducido a nombre real nuevamente**

# %%
# Diccionario de mapeo de códigos a descripciones
codigo_a_texto = {
    "subgrupo_C1_2": "C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MENOS DE 5 TONOS HASTA SER ATENDIDOS.",
    "subgrupo_C1_3": "C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MENOS DE 20 SEGUNDOS HASTA SER ATENDIDOS.",
    "subgrupo_C1_4": "C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MÁS DE 5 TONOS HASTA SER ATENDIDOS.",
    "subgrupo_C1_5": "C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MÁS DE 20 SEGUNDOS HASTA SER ATENDIDOS.",
    "subgrupo_C1_6": "C1. TIEMPO DE RESPUESTA.COND.LA LLAMADA NO HA SIDO ATENDIDA TRAS PASARSE EL PLAZO DE 4 MINUTOS DE ESPERA Y NO SER ATENDIDOS POR UN ASESOR.",
    "subgrupo_C2_1": "C2. ACCEDER AL SERVICIO DESEADO.COND.EL MENSAJE DEL IVR TIENE UNA DURACIÓN INFERIOR AL MINUTO.",
    "subgrupo_C2_2": "C2. ACCEDER AL SERVICIO DESEADO.COND.EL MENSAJE DEL IVR TIENE UNA DURACIÓN SUPERIOR AL MINUTO.",
    "subgrupo_C2_3": "C2. ACCEDER AL SERVICIO DESEADO.OBS",
    "subgrupo_C3_1": "C3. CONTACTAR/HABLAR CON UN ASESOR.COND.TRANSCURRE MENOS DE 1 MINUTO HASTA QUE HABLAMOS CON UN ASESOR.",
    "subgrupo_C3_2": "C3. CONTACTAR/HABLAR CON UN ASESOR.COND.TRANSCURREN ENTRE 1 Y 2 MINUTOS HASTA QUE HABLAMOS CON UN ASESOR.",
    "subgrupo_C3_3": "C3. CONTACTAR/HABLAR CON UN ASESOR.COND.TRANSCURREN ENTRE 2 Y 4 MINUTOS HASTA QUE HABLAMOS CON UN ASESOR.",
    "subgrupo_C3_4": "C3. CONTACTAR/HABLAR CON UN ASESOR.OBS",
    "subgrupo_C4_1": "C4. TIEMPO DE TRANSFERENCIA.COND.EL ASESOR TRANSFIERE LA LLAMADA DEL CLIENTE EN UN TIEMPO INFERIOR A 30 SEGUNDOS.",
    "subgrupo_C4_2": "C4. TIEMPO DE TRANSFERENCIA.COND.EL ASESOR TRANSFIERE LA LLAMADA DEL CLIENTE EN UN TIEMPO ENTRE 30 Y 45 SEGUNDOS.",
    "subgrupo_C4_3": "C4. TIEMPO DE TRANSFERENCIA.COND.EL ASESOR/S TRANSFIERE LA LLAMADA DEL CLIENTE EN UN TIEMPO SUPERIOR A LOS 45 SEGUNDOS.",
    "subgrupo_C4_4": "C4. TIEMPO DE TRANSFERENCIA.OBS",
    "subgrupo_C5_1": "C5. LLAMADA EN ESPERA (TÚNEL).COND.SE PRODUCEN DOS ESPERAS INFERIORES A 30 SEGUNDOS CON PREVIO AVISO PARA LA MISMA CONSULTA.",
    "subgrupo_C5_2": "C5. LLAMADA EN ESPERA (TÚNEL).COND.SE PRODUCE UNA ESPERA INFERIOR A 30 SEGUNDOS CON PREVIO AVISO.",
    "subgrupo_C5_3": "C5. LLAMADA EN ESPERA (TÚNEL).COND.SE PRODUCE UNA ESPERA INFERIOR A 30 SEGUNDOS SIN PREVIO AVISO.",
    "subgrupo_C5_4": "C5. LLAMADA EN ESPERA (TÚNEL).COND.SE PRODUCE UNA ESPERA SUPERIOR A 30 SEGUNDOS.",
    "subgrupo_C5_5": "C5. LLAMADA EN ESPERA (TÚNEL).COND.SE PRODUCEN DOS ESPERAS PARA CONSULTAS DIFERENTES.",
    "subgrupo_C5_6": "C5. LLAMADA EN ESPERA (TÚNEL).COND.SE PRODUCEN DOS ESPERAS PARA LA MISMA CONSULTA SUPERIORES A 30 SEGUNDOS.",
    "subgrupo_C5_7": "C5. LLAMADA EN ESPERA (TÚNEL).OBS",
    "subgrupo_C6_1": "C6. TOMA DE CONTACTO.COND.EL ASESOR SE IDENTIFICA CON SU NOMBRE, CON UNA VELOCIDAD DE DISCURSO Y ELOCUCIÓN ADECUADAS.",
    "subgrupo_C6_2": "C6. TOMA DE CONTACTO.COND.EL ASESOR MANTIENE UNA VELOCIDAD Y ELOCUCIÓN ADECUADAS, PERO NO SE IDENTIFICA CON SU NOMBRE.",
    "subgrupo_C6_3": "C6. TOMA DE CONTACTO.COND.EL ASESOR SE IDENTIFICA CON SU NOMBRE, PERO CON UNA VELOCIDAD Y ELOCUCIÓN POCO ADECUADAS.",
    "subgrupo_C6_4": "C6. TOMA DE CONTACTO.COND.EL ASESOR NI SE IDENTIFICA CON SU NOMBRE NI SU VELOCIDAD Y ELOCUCIÓN ES BUENA.",
    "subgrupo_C6_5": "C6. TOMA DE CONTACTO.OBS",
    "subgrupo_C7_1": "C7. IDENTIFICACIÓN.COND.LA GRABACIÓN IVR SÍ IDENTIFICA A LA EMPRESA CON SU NOMBRE.",
    "subgrupo_C7_2": "C7. IDENTIFICACIÓN.COND.LA GRABACIÓN IVR NO IDENTIFICA A LA EMPRESA CON SU NOMBRE.",
    "subgrupo_C7_3": "C7. IDENTIFICACIÓN.OBS",
    "subgrupo_C8_1": "C8. PERSONALIZACIÓN.COND.EL ASESOR PERSONALIZA LA CONVERSACIÓN CON EL NOMBRE DEL CLIENTE.",
    "subgrupo_C8_2": "C8. PERSONALIZACIÓN.COND.EL ASESOR VUELVE A PEDIR EL NOMBRE DEL CLIENTE CUANDO LO SABE Y LO HA UTILIZADO ANTES.",
    "subgrupo_C8_3": "C8. PERSONALIZACIÓN.COND.EL ASESOR SE EQUIVOCA CON EL NOMBRE DEL CLIENTE.",
    "subgrupo_C8_4": "C8. PERSONALIZACIÓN.COND.EL ASESOR NO PERSONALIZA LA CONVERSACIÓN EN NINGÚN MOMENTO DE ESTA.",
    "subgrupo_C8_5": "C8. PERSONALIZACIÓN.OBS",
    "subgrupo_C9_1": "C9. MOTIVO DE CONTACTO.COND.EL ASESOR REALIZA EL SONDEO NECESARIO PARA IDENTIFICAR LA NECESIDAD DEL CLIENTE.",
    "subgrupo_C9_2": "C9. MOTIVO DE CONTACTO.COND.EL ASESOR NO REALIZA EL SONDEO NECESARIO PARA IDENTIFICAR LA NECESIDAD DEL CLIENTE.",
    "subgrupo_C9_3": "C9. MOTIVO DE CONTACTO.OBS",
    "subgrupo_C10_1": "C10. REFORMULACIÓN.COND.EL ASESOR UTILIZA LA CONSULTA DEL CLIENTE PARA RESPONDER A ELLA.",
    "subgrupo_C10_2": "C10. REFORMULACIÓN.COND.EL ASESOR REFORMULA LA CONSULTA DEL CLIENTE PARA RESPONDER A ELLA.",
    "subgrupo_C10_3": "C10. REFORMULACIÓN.COND.EL ASESOR RESPONDE DIRECTAMENTE A LA PETICIÓN SIN HABER UTILIZADO LA CONSULTA DEL CLIENTE.",
    "subgrupo_C10_4": "C10. REFORMULACIÓN.COND.EL ASESOR RESPONDE DIRECTAMENTE A LA PETICIÓN SIN HABER REFORMULADO LA CONSULTA DEL CLIENTE.",
    "subgrupo_C10_5": "C10. REFORMULACIÓN.OBS",
    "subgrupo_C11_1": "C11. DIRECCIÓN DE LA LLAMADA.COND.DIRIGE LA SECUENCIA DE LLAMADA MANTENIENDO EL ENFOQUE.",
    "subgrupo_C11_2": "C11. DIRECCIÓN DE LA LLAMADA.COND.NO ALARGA NI PRECIPITA DE MANERA INNECESARIA EL CIERRE DE CONVERSACIÓN.",
    "subgrupo_C11_3": "C11. DIRECCIÓN DE LA LLAMADA.COND.NO DIRIGE LA SECUENCIA DE LLAMADA MANTENIENDO EL ENFOQUE.",
    "subgrupo_C11_4": "C11. DIRECCIÓN DE LA LLAMADA.COND.ALARGA O PRECIPITA DE MANERA INNECESARIA EL CIERRE DE CONVERSACIÓN.",
    "subgrupo_C11_5": "C11. DIRECCIÓN DE LA LLAMADA.OBS",
    "subgrupo_C12_1": "C12. TRANSFERENCIA SIN FRICCIÓN.COND.EL CLIENTE NO TIENE QUE VOLVER A EXPLICAR LA CONSULTA AL ASESOR AL QUE SE HA TRANSFERIDO.",
    "subgrupo_C12_2": "C12. TRANSFERENCIA SIN FRICCIÓN.COND.EL CLIENTE EXPLICA PARCIALMENTE LA CONSULTA AL ASESOR AL QUE SE HA TRANSFERIDO.",
    "subgrupo_C12_3": "C12. TRANSFERENCIA SIN FRICCIÓN.COND.EL CLIENTE TIENE QUE VOLVER A EXPLICAR DE NUEVO LA CONSULTA AL ASESOR AL QUE SE HA TRANSFERIDO.",
    "subgrupo_C12_4": "C12. TRANSFERENCIA SIN FRICCIÓN.OBS",
    "subgrupo_C13_1": "C13. SABER ORIENTAR.COND.EL PRIMER ASESOR CONSIGUE TRANSFERIR LA LLAMADA DEL CLIENTE AL ASESOR ADECUADO A LA PRIMERA.",
    "subgrupo_C13_2": "C13. SABER ORIENTAR.COND.EL PRIMER ASESOR NO CONSIGUE TRANSFERIR LA LLAMADA DEL CLIENTE AL ASESOR ADECUADO A LA PRIMERA, TENIENDO QUE VOLVER A TRANSFERIR LA LLAMADA.",
    "subgrupo_C13_3": "C13. SABER ORIENTAR.OBS",
    "subgrupo_C14_1": "C14. SABER ESCUCHAR/ESCUCHA ACTIVA.COND.EL ASESOR NO HA INTERRUMPIDO AL CLIENTE EN NINGÚN MOMENTO DE LA LLAMADA.",
    "subgrupo_C14_2": "C14. SABER ESCUCHAR/ESCUCHA ACTIVA.COND.EL ASESOR HA INTERRUMPIDO AL CLIENTE EN ALGÚN MOMENTO DE LA LLAMADA, PERO SE HA DISCULPADO POR ELLO.",
    "subgrupo_C14_3": "C14. SABER ESCUCHAR/ESCUCHA ACTIVA.COND.EL ASESOR INTERRUMPE AL CLIENTE EN DIFERENTES MOMENTOS DE LA LLAMADA, SIN DISCULPARSE POR ELLO.",
    "subgrupo_C14_4": "C14. SABER ESCUCHAR/ESCUCHA ACTIVA.OBS",
    "subgrupo_C15_1": "C15. SABER DECIR (CAPACIDAD EXPRESIÓN).COND.EL ASESOR UTILIZA UN DISCURSO ADAPTADO A LA CONSULTA DEL CLIENTE, SIN TÉRMINOS INCOMPRENSIBLES.",
    "subgrupo_C15_2": "C15. SABER DECIR (CAPACIDAD EXPRESIÓN).COND.EL ASESOR UTILIZA EN SU DISCURSO ALGUNOS TECNICISMOS O PALABRAS CLAVE, LAS CUÁLES NO EXPLICA SU SIGNIFICADO PARA FACILITAR LA COMPRENSIÓN DEL CLIENTE.",
    "subgrupo_C15_3": "C15. SABER DECIR (CAPACIDAD EXPRESIÓN).COND.EL ASESOR UTILIZA UN DISCURSO PLAGADO DE TECNICISMOS Y SIGLAS INCOMPRENSIBLES, POCO ENTENDIBLES PARA EL CLIENTE.",
    "subgrupo_C15_4": "C15. SABER DECIR (CAPACIDAD EXPRESIÓN).OBS",
    "subgrupo_C16_1": "C16. CALIDAD DEL TONO.COND.EL ASESOR MANTIENE UN TONO Y DISCURSO ADECUADO DURANTE TODA LA LLAMADA.",
    "subgrupo_C16_2": "C16. CALIDAD DEL TONO.COND.DISCURSO ROBOTIZADO.",
    "subgrupo_C16_3": "C16. CALIDAD DEL TONO.COND.EL ASESOR ATIENDE CON PRISA, PROCURA FINALIZAR LA LLAMADA.",
    "subgrupo_C16_4": "C16. CALIDAD DEL TONO.COND.TONO FRIO Y DISTANTE. AUSENCIA DE CONTACTO EMOCIONAL.",
    "subgrupo_C16_5": "C16. CALIDAD DEL TONO.COND.EN ALGÚN MOMENTO DE LA LLAMADA NO SE ENTIENDE AL ASESOR.",
    "subgrupo_C16_6": "C16. CALIDAD DEL TONO.COND.EL ASESOR UTILIZA IRONÍA O SARCASMO.",
    "subgrupo_C16_7": "C16. CALIDAD DEL TONO.COND.EL ASESOR SE MUESTRA POCO CORDIAL AUNQUE EDUCADO.",
    "subgrupo_C16_8": "C16. CALIDAD DEL TONO.COND.EL ASESOR NO ENTREGA RESPUESTA. DEMASIADO INSISTENTE EN LLAMAR EN UN MOMENTO POSTERIOR.",
    "subgrupo_C16_9": "C16. CALIDAD DEL TONO.COND.A PESAR QUE LA ATENCIÓN ES CORRECTA Y SE RESUELVE LA CONSULTA, EL ASESOR TRANSMITE POCO DINAMISMO EN LA LLAMADA. TONO MONÓTONO.",
    "subgrupo_C16_10": "C16. CALIDAD DEL TONO.COND.TONO POCO AMABLE, NADA EMPÁTICO CON EL CLIENTE.",
    "subgrupo_C16_11": "C16. CALIDAD DEL TONO.OBS",
    "subgrupo_C17_1": "C17. IMPRESIÓN GENERAL.COND.EL ASESOR DEMUESTRA SEGURIDAD DURANTE LA LLAMADA, OFRECIENDO EXPLICACIONES CLARAS.",
    "subgrupo_C17_2": "C17. IMPRESIÓN GENERAL.COND.EL ASESOR DEMUESTRA EDUCACIÓN AL ATENDER LA LLAMADA CON AMABILIDAD Y CORDIALIDAD.",
    "subgrupo_C17_3": "C17. IMPRESIÓN GENERAL.COND.EL ASESOR NO DEMUESTRA SEGURIDAD DURANTE LA LLAMADA, DUDANDO O TITUBEANDO EN DIFERENTES MOMENTOS DE ESTA.",
    "subgrupo_C17_4": "C17. IMPRESIÓN GENERAL.COND.EL ASESOR NO DEMUESTRA EDUCACIÓN AL ATENDER LA LLAMADA CON POCA AMABILIDAD.",
    "subgrupo_C17_5": "C17. IMPRESIÓN GENERAL.COND.LA LLAMADA NO HA SIDO ATENDIDA TRAS PASARSE EL PLAZO DE 4 MINUTOS DE ESPERA Y NO SER ATENDIDOS POR UN ASESOR.",
    "subgrupo_C17_6": "C17. IMPRESIÓN GENERAL.OBS",
    "subgrupo_C18_1": "C18. CALIDAD DEL ENTORNO.COND.NO SE DETECTAN INTERFERENCIAS O MICROCORTES DURANTE EL TRANSCURSO DE LA CONVERSACIÓN.",
    "subgrupo_C18_2": "C18. CALIDAD DEL ENTORNO.COND.NO SE DETECTA RUIDO AMBIENTAL DURANTE EL TRANSCURSO DE LA CONVERSACIÓN.",
    "subgrupo_C18_3": "C18. CALIDAD DEL ENTORNO.COND.SE DETECTAN INTERFERENCIAS O MICROCORTES DURANTE EL TRANSCURSO DE LA CONVERSACIÓN.",
    "subgrupo_C18_4": "C18. CALIDAD DEL ENTORNO.COND.SE DETECTA RUIDO AMBIENTAL DURANTE EL TRANSCURSO DE LA CONVERSACIÓN.",
    "subgrupo_C18_5": "C18. CALIDAD DEL ENTORNO.OBS",
    "subgrupo_C19_1": "C19. CALIDAD DE LA RESPUESTA.COND.EL ASESOR OFRECE UNA RESPUESTA ADECUADA A LA CONSULTA DEL CLIENTE. MUESTRA CONOCIMIENTO (ENTENDIMIENTO) DE LA CONSULTA O PRODUCTO.",
    "subgrupo_C19_2": "C19. CALIDAD DE LA RESPUESTA.COND.EL ASESOR OFRECE UNA RESPUESTA ORIENTATIVA, Y SE INDICA QUE LLAME A OTRO NÚMERO/SUCURSAL/WEB PARA TENER LA INFORMACIÓN. MUESTRA CONOCIMIENTO NO ASENTADO (ENTENDIMIENTO) DE LA CONSULTA O PRODUCTO.",
    "subgrupo_C19_3": "C19. CALIDAD DE LA RESPUESTA.COND.EL ASESOR ENVÍA LA RESPUESTA POR CORREO. EN OTRAS OCASIONES SE HA RESPONDIDO A LA CONSULTA DIRECTAMENTE, SIN NECESIDAD DE OBTENERLA POR OTRA VÍA.",
    "subgrupo_C19_4": "C19. CALIDAD DE LA RESPUESTA.COND.EL ASESOR NO OFRECE UNA RESPUESTA COMPLETA. EN OTRAS OCASIONES SE HA OFRECIDO UNA INFORMACIÓN COMPLETA. NO APORTA INFORMACIÓN NECESARIA PARA QUE EL CLIENTE LO ENTIENDA PERFECTAMENTE.",
    "subgrupo_C19_5": "C19. CALIDAD DE LA RESPUESTA.COND.NO SE OFRECE UNA RESPUESTA COMPLETA, SINO QUE SE REQUIERE QUE DEMOS NUESTROS DATOS. EN OTRAS OCASIONES SE HA OFRECIDO UNA INFORMACIÓN SIN REQUERIR APORTAR DATOS.",
    "subgrupo_C19_6": "C19. CALIDAD DE LA RESPUESTA.COND.EL ASESOR NO SE CENTRA EN OFRECER LA RESPUESTA SOLICITADA POR EL CLIENTE. APORTA INFORMACIÓN POCO INFLUYENTE PARA LA CONSULTA.",
    "subgrupo_C19_7": "C19. CALIDAD DE LA RESPUESTA.COND.LA RESPUESTA NO ES COMPLETA, AL INTENTAR TRANSFERIR EL ASESOR LA LLAMADA AL DEPARTAMENTO CORRESPONDIENTE SIN ÉXITO AL ESTAR FUERA DEL HORARIO DE ATENCIÓN.",
    "subgrupo_C19_8": "C19. CALIDAD DE LA RESPUESTA.COND.LA RESPUESTA NO ES COMPLETA, AL INTENTAR EL ASESOR CONSEGUIR LA INFORMACIÓN POR OTRA VÍA Y NO CONSEGUIRLO (NO LE COGEN EL TELÉFONO, LA LÍNEA ESTÁ OCUPADA O ALGUIEN ESTÁ OCUPADO PARA HACER LA CONSULTA).",
    "subgrupo_C19_9": "C19. CALIDAD DE LA RESPUESTA.COND.LA RESPUESTA ES ESCUETA. CONTESTA CON MONOSÍLABOS: NO EXPLICA NI DA OPCIONES A LA PREGUNTA SOLICITADA.",
    "subgrupo_C19_10": "C19. CALIDAD DE LA RESPUESTA.COND.RESPUESTA NO ADECUADA, DIFERENTE A LA CONSULTA. FALTA DE ESCUCHA ACTIVA. O FALTA DE CONOCIMIENTO (ENTENDIMIENTO) DE LA CONSULTA O PRODUCTO.",
    "subgrupo_C19_11": "C19. CALIDAD DE LA RESPUESTA.COND.EL ASESOR NO OFRECE UNA RESPUESTA, SINO QUE SE INDICA OTRO NÚMERO AL QUE LLAMAR/MAIL QUE ENVIAR/WEB QUE VISITAR/RED SOCIAL A CONSULTAR/CHAT AL QUE HABLAR.",
    "subgrupo_C19_12": "C19. CALIDAD DE LA RESPUESTA.COND.LA LLAMADA NO HA SIDO ATENDIDA TRAS PASARSE EL PLAZO DE 4 MINUTOS DE ESPERA Y NO SER ATENDIDOS POR UN ASESOR.",
    "subgrupo_C19_13": "C19. CALIDAD DE LA RESPUESTA.OBS",
    "subgrupo_C20_1": "C20. PROACTIVIDAD.COND.INFORMACIÓN ÚTIL, QUE APORTA VALOR AL CLIENTE.",
    "subgrupo_C20_2": "C20. PROACTIVIDAD.COND.ADAPTA LOS PROCESOS EN LA MEDIDA DE LO POSIBLE Y OFRECE ALTERNATIVAS.",
    "subgrupo_C20_3": "C20. PROACTIVIDAD.COND.TOMA DECISIONES EFICIENTES Y EFICACES PARA RESOLVER LA LLAMADA.",
    "subgrupo_C20_4": "C20. PROACTIVIDAD.COND.EXCESO DE INFORMACIÓN NO ÚTIL, QUE NO APORTA VALOR AL CLIENTE.",
    "subgrupo_C20_5": "C20. PROACTIVIDAD.COND.NO ADAPTA LOS PROCESOS EN LA MEDIDA DE LO POSIBLE Y SÓLO OFRECE ALTERNATIVAS POR INSISTENCIA DEL CLIENTE.",
    "subgrupo_C20_6": "C20. PROACTIVIDAD.COND.NO TOMA DECISIONES EFICIENTES Y EFICACES PARA RESOLVER LA LLAMADA.",
    "subgrupo_C20_7": "C20. PROACTIVIDAD.OBS",
    "subgrupo_C21_1": "C21. SOLUCIÓN AL PRIMER CONTACTO (FCR).COND.SE SOLUCIONA LA CONSULTA EN EL PRIMER CONTACTO Y NO ES NECESARIO REALIZAR UN CONTACTO POSTERIOR.",
    "subgrupo_C21_2": "C21. SOLUCIÓN AL PRIMER CONTACTO (FCR).COND.NO SE SOLUCIONA LA CONSULTA EN EL PRIMER CONTACTO Y ES NECESARIO REALIZAR UN CONTACTO POSTERIOR.",
    "subgrupo_C21_3": "C21. SOLUCIÓN AL PRIMER CONTACTO (FCR).OBS",
    "subgrupo_C22_1": "C22. IMAGEN CORPORATIVA.COND.LA PROFESIONALIDAD DEL GESTOR TRASLADA UNA IMAGEN POSITIVA.",
    "subgrupo_C22_2": "C22. IMAGEN CORPORATIVA.COND.SE DISCULPA ANTE LAS MOLESTIAS EVIDENCIADAS POR EL CLIENTE DURANTE LA LLAMADA.",
    "subgrupo_C22_3": "C22. IMAGEN CORPORATIVA.COND.LA FALTA DE PROFESIONALIDAD DEL GESTOR TRASLADA UNA IMAGEN NEGATIVA.",
    "subgrupo_C22_4": "C22. IMAGEN CORPORATIVA.COND.NO SE DISCULPA ANTE LAS MOLESTIAS EVIDENCIADAS POR EL CLIENTE DURANTE LA LLAMADA.",
    "subgrupo_C22_5": "C22. IMAGEN CORPORATIVA.OBS",
    "subgrupo_C23_1": "C23. DESPEDIDA.COND.EL ASESOR SE DESPIDE DEL CLIENTE CON SU NOMBRE, HABIÉNDOSE ASEGURADO DE QUE TODAS SUS DUDAS ESTÉN RESUELTAS.",
    "subgrupo_C23_2": "C23. DESPEDIDA.COND.EL ASESOR SE DESPIDE DEL CLIENTE CON SU NOMBRE, HABIÉNDOSE ASEGURADO DE QUE TODAS SUS DUDAS ESTÉN RESUELTAS.",
    "subgrupo_C23_3": "C23. DESPEDIDA.COND.EL ASESOR SE ASEGURA QUE TODAS LAS DUDAS DEL CLIENTE ESTÉN RESUELTAS, PERO NO UTILIZA EL NOMBRE DE ESTE EN LA DESPEDIDA.",
    "subgrupo_C23_4": "C23. DESPEDIDA.COND.EL ASESOR NI SE DESPIDE DEL CLIENTE CON SU NOMBRE NI SE ASEGURA QUE LE QUEDEN DUDAS POR RESOLVER.",
    "subgrupo_C23_5": "C23. DESPEDIDA.COND.NO HA HABIDO DESPEDIDA AL NO HABERSE TRANSFERIDO LA LLAMADA.",
    "subgrupo_C23_6": "C23. DESPEDIDA.COND.NO HA HABIDO DESPEDIDA AL CORTARSE LA TRANSFERENCIA.",
    "subgrupo_C23_7": "C23. DESPEDIDA.OBS"
}

# Reemplazar los códigos por los textos en la primera columna
columna_original = resultado_final.columns[0]
resultado_final[columna_original] = resultado_final[columna_original].map(codigo_a_texto).fillna(resultado_final[columna_original])

# Mostrar los primeros resultados para verificar
resultado_final
# Out:
#                                               Subgrupo  Penalizaciones
# 0    C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MENOS...               0
# 1    C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MENOS...               0
# 2    C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MÁS D...               0
# 3    C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MÁS D...               0
# 4    C1. TIEMPO DE RESPUESTA.COND.LA LLAMADA NO HA ...               0
# ..                                                 ...             ...
# 116  C8. PERSONALIZACIÓN.COND.EL ASESOR NO PERSONAL...              94
# 117                            C8. PERSONALIZACIÓN.OBS               0
# 118  C9. MOTIVO DE CONTACTO.COND.EL ASESOR REALIZA ...               0
# 119  C9. MOTIVO DE CONTACTO.COND.EL ASESOR NO REALI...               0
# 120                         C9. MOTIVO DE CONTACTO.OBS               0
#
# [121 rows x 2 columns]

# %% [markdown]
# **Se añaden variables globales**

# %%
# Aseguramos que la columna con los subgrupos está correctamente identificada
columna_codigos = resultado_final.columns[0]

# Creamos un diccionario para saber a qué grupo pertenece cada subgrupo
grupo_por_codigo = {
    "C1": "C1. TIEMPO DE RESPUESTA",
    "C2": "C2. ACCEDER AL SERVICIO DESEADO",
    "C3": "C3. CONTACTAR/HABLAR CON UN ASESOR",
    "C4": "C4. TIEMPO DE TRANSFERENCIA",
    "C5": "C5. LLAMADA EN ESPERA (TÚNEL)",
    "C6": "C6. TOMA DE CONTACTO",
    "C7": "C7. IDENTIFICACIÓN",
    "C8": "C8. PERSONALIZACIÓN",
    "C9": "C9. MOTIVO DE CONTACTO",
    "C10": "C10. REFORMULACIÓN",
    "C11": "C11. DIRECCIÓN DE LA LLAMADA",
    "C12": "C12. TRANSFERENCIA SIN FRICCIÓN",
    "C13": "C13. SABER ORIENTAR",
    "C14": "C14. SABER ESCUCHAR/ESCUCHA ACTIVA",
    "C15": "C15. SABER DECIR (CAPACIDAD EXPRESIÓN)",
    "C16": "C16. CALIDAD DEL TONO",
    "C17": "C17. IMPRESIÓN GENERAL",
    "C18": "C18. CALIDAD DEL ENTORNO",
    "C19": "C19. CALIDAD DE LA RESPUESTA",
    "C20": "C20. PROACTIVIDAD",
    "C21": "C21. SOLUCIÓN AL PRIMER CONTACTO (FCR)",
    "C22": "C22. IMAGEN CORPORATIVA",
    "C23": "C23. DESPEDIDA"
}

# Extraer el código del grupo (C1, C2, ..., C23)
resultado_final['grupo_codigo'] = resultado_final[columna_codigos].str.extract(r'(C\d+)')

# Agregar el nombre del grupo a partir del código
resultado_final['grupo_nombre'] = resultado_final['grupo_codigo'].map(grupo_por_codigo)

# Crear DataFrame final con filas vacías para insertar los nombres de los grupos
df_final = pd.DataFrame(columns=resultado_final.columns)

# Insertar filas con el nombre del grupo
for grupo, df_grupo in resultado_final.groupby('grupo_nombre', sort=False):
    fila_grupo = pd.DataFrame({columna_codigos: [grupo]})
    df_final = pd.concat([df_final, fila_grupo, df_grupo], ignore_index=True)

# Si querés eliminar las columnas auxiliares
df_final = df_final.drop(columns=['grupo_codigo', 'grupo_nombre'])

# Mostrar resultado
print(df_final.head(20))  # podés ajustar este número
# Out:
#                                              Subgrupo  Penalizaciones
# 0                             C1. TIEMPO DE RESPUESTA             NaN
# 1   C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MENOS...             0.0
# 2   C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MENOS...             0.0
# 3   C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MÁS D...             0.0
# 4   C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MÁS D...             0.0
# 5   C1. TIEMPO DE RESPUESTA.COND.LA LLAMADA NO HA ...             0.0
# 6                                  C10. REFORMULACIÓN             NaN
# 7   C10. REFORMULACIÓN.COND.EL ASESOR UTILIZA LA C...             0.0
# 8   C10. REFORMULACIÓN.COND.EL ASESOR REFORMULA LA...             0.0
# 9   C10. REFORMULACIÓN.COND.EL ASESOR RESPONDE DIR...            37.0
# 10  C10. REFORMULACIÓN.COND.EL ASESOR RESPONDE DIR...            15.0
# 11                             C10. REFORMULACIÓN.OBS             0.0
# ...

# %% [markdown]
# **Cargar competencias y PE para añadir a df creado**

# %%
# Ruta del archivo Excel en tu Google Drive
file_path2 = '/content/drive/MyDrive/Sottotempo/PE y competencias/PE y competencias llamadas.xlsx'

# Cargar el archivo Excel
PE = pd.read_excel(file_path2)

PE.head()
# Out:
#        subgrupos                                          variables  \
# 0            NaN                            C1. TIEMPO DE RESPUESTA
# 1  subgrupo_C1_2  C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MENOS...
# 2  subgrupo_C1_3  C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MENOS...
# 3  subgrupo_C1_4  C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MÁS D...
# 4  subgrupo_C1_5  C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MÁS D...
#
#                                                   PE Competencia
# 0                                                NaN         NaN
# 1  Transcurren menos de 5 tonos hasta ser atendidos.         NaN
# 2  Transcurren menos de 20 segundos hasta ser ate...         NaN
# 3    Transcurren más de 5 tonos hasta ser atendidos.         NaN
# 4  Transcurren más de 20 segundos hasta ser atend...         NaN

# %% [markdown]
# Se agregan al df las competencias y PE

# %%
# Crear un diccionario para mapear la variable a PE y Competencia
variable_to_pe_competencia = {}

# Asumimos que el nuevo archivo tiene las columnas: 'Subgrupo', 'Variables', 'PE', 'Competencia'
for _, row in PE.iterrows():
    variable_to_pe_competencia[row['variables']] = {'PE': row['PE'], 'Competencia': row['Competencia']}

# Ahora, vamos a añadir las columnas 'PE' y 'Competencia' a df_final
# Para esto, necesitamos recorrer df_final y asignar 'PE' y 'Competencia' según corresponda a la variable

df_final['PE'] = df_final['Subgrupo'].map(lambda var: variable_to_pe_competencia.get(var, {}).get('PE', None))
df_final['Competencia'] = df_final['Subgrupo'].map(lambda var: variable_to_pe_competencia.get(var, {}).get('Competencia', None))

# Mostramos el resultado final
print(df_final)
# Out:
#                                               Subgrupo  Penalizaciones  \
# 0                              C1. TIEMPO DE RESPUESTA             NaN
# 1    C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MENOS...             0.0
# 2    C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MENOS...             0.0
# 3    C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MÁS D...             0.0
# 4    C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MÁS D...             0.0
# ..                                                 ...             ...
# 139                            C8. PERSONALIZACIÓN.OBS             0.0
# 140                             C9. MOTIVO DE CONTACTO             NaN
# 141  C9. MOTIVO DE CONTACTO.COND.EL ASESOR REALIZA ...             0.0
# 142  C9. MOTIVO DE CONTACTO.COND.EL ASESOR NO REALI...             0.0
# 143                         C9. MOTIVO DE CONTACTO.OBS             0.0
#
#                                                     PE   Competencia
# ...

# %% [markdown]
# **Para descargar el df a excel, con todas las modifaciones ya realizadas**

# %%
# Guardamos el DataFrame 'resultados_df' con los nombres reales en un archivo Excel
output_path = '/content/resultados_df_telefono.xlsx'
df_final.to_excel(output_path, index=False)

# Descargar el archivo generado
from google.colab import files
files.download(output_path)

# %% [markdown]
# # **Ejecutar solo para MAIL O FORMULARIO**

# %%
import pandas as pd

# Ruta del archivo Excel en tu Google Drive
file_path = '/content/drive/MyDrive/Sottotempo/Mail.xlsx'

# Cargar el archivo Excel
df2 = pd.read_excel(file_path)

df2.head()
# Out:
#    C1 subgrupo_C1_1 subgrupo_C1_2 subgrupo_C1_3 subgrupo_C1_4 subgrupo_C1_5  \
# 0   2             1
# 1   2             1
# 2   2             1
# 3   2             1
# 4   2             1
#
#   subgrupo_C1_6 C2 subgrupo_C2_1 subgrupo_C2_2  ... subgrupo_C18_3  \
# 0                2             1                ...              0
# 1                2             1                ...              0
# 2                2             1                ...              0
# 3                2             1                ...              0
# 4                2             1                ...              0
#
#   subgrupo_C18_4 subgrupo_C18_5 subgrupo_C18_6 subgrupo_C18_7 C19  \
# 0                                                               2
# 1                                                               2
# 2                                                               2
# 3                                                               2
# ...

# %%
# Diccionario de mapeo de códigos a descripciones
codigo_a_texto = {
    "C1. TIEMPO DE RESPUESTA": "C1",
    "C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MENOS DE 5 TONOS HASTA SER ATENDIDOS.": "subgrupo_C1_2",
    "C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MENOS DE 20 SEGUNDOS HASTA SER ATENDIDOS.": "subgrupo_C1_3",
    "C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MÁS DE 5 TONOS HASTA SER ATENDIDOS.": "subgrupo_C1_4",
    "C1. TIEMPO DE RESPUESTA.COND.TRANSCURREN MÁS DE 20 SEGUNDOS HASTA SER ATENDIDOS.": "subgrupo_C1_5",
    "C2. ACCEDER AL SERVICIO DESEADO": "C2",
    "C1. TIEMPO DE RESPUESTA.COND.LA LLAMADA NO HA SIDO ATENDIDA TRAS PASARSE EL PLAZO DE 4 MINUTOS DE ESPERA Y NO SER ATENDIDOS POR UN ASESOR.": "subgrupo_C1_6",
    "C2. ACCEDER AL SERVICIO DESEADO.COND.EL MENSAJE DEL IVR TIENE UNA DURACIÓN INFERIOR AL MINUTO.": "subgrupo_C2_1",
    "C2. ACCEDER AL SERVICIO DESEADO.COND.EL MENSAJE DEL IVR TIENE UNA DURACIÓN SUPERIOR AL MINUTO.": "subgrupo_C2_2",
    "C2. ACCEDER AL SERVICIO DESEADO.OBS": "subgrupo_C2_3",
    "C3. CONTACTAR/HABLAR CON UN ASESOR": "C3",
    "C3. CONTACTAR/HABLAR CON UN ASESOR.COND.TRANSCURRE MENOS DE 1 MINUTO HASTA QUE HABLAMOS CON UN ASESOR.": "subgrupo_C3_1",
    "C3. CONTACTAR/HABLAR CON UN ASESOR.COND.TRANSCURREN ENTRE 1 Y 2 MINUTOS HASTA QUE HABLAMOS CON UN ASESOR.": "subgrupo_C3_2",
    "C3. CONTACTAR/HABLAR CON UN ASESOR.COND.TRANSCURREN ENTRE 2 Y 4 MINUTOS HASTA QUE HABLAMOS CON UN ASESOR.": "subgrupo_C3_3",
    "C3. CONTACTAR/HABLAR CON UN ASESOR.OBS": "subgrupo_C3_4",
    "C4. TIEMPO DE TRANSFERENCIA": "C4",
    "C4. TIEMPO DE TRANSFERENCIA.COND.EL ASESOR TRANSFIERE LA LLAMADA DEL CLIENTE EN UN TIEMPO INFERIOR A 30 SEGUNDOS.": "subgrupo_C4_1",
    "C4. TIEMPO DE TRANSFERENCIA.COND.EL ASESOR TRANSFIERE LA LLAMADA DEL CLIENTE EN UN TIEMPO ENTRE 30 Y 45 SEGUNDOS.": "subgrupo_C4_2",
    "C4. TIEMPO DE TRANSFERENCIA.COND.EL ASESOR/S TRANSFIERE LA LLAMADA DEL CLIENTE EN UN TIEMPO SUPERIOR A LOS 45 SEGUNDOS.": "subgrupo_C4_3",
    "C4. TIEMPO DE TRANSFERENCIA.OBS": "subgrupo_C4_4",
    "C5. LLAMADA EN ESPERA (TÚNEL)": "C5",
    "C5. LLAMADA EN ESPERA (TÚNEL).COND.SE PRODUCEN DOS ESPERAS INFERIORES A 30 SEGUNDOS CON PREVIO AVISO PARA LA MISMA CONSULTA.": "subgrupo_C5_1",
    "C5. LLAMADA EN ESPERA (TÚNEL).COND.SE PRODUCE UNA ESPERA INFERIOR A 30 SEGUNDOS CON PREVIO AVISO.": "subgrupo_C5_2",
    "C5. LLAMADA EN ESPERA (TÚNEL).COND.SE PRODUCE UNA ESPERA INFERIOR A 30 SEGUNDOS SIN PREVIO AVISO.": "subgrupo_C5_3",
    "C5. LLAMADA EN ESPERA (TÚNEL).COND.SE PRODUCE UNA ESPERA SUPERIOR A 30 SEGUNDOS.": "subgrupo_C5_4",
    "C5. LLAMADA EN ESPERA (TÚNEL).COND.SE PRODUCEN DOS ESPERAS PARA CONSULTAS DIFERENTES.": "subgrupo_C5_5",
    "C5. LLAMADA EN ESPERA (TÚNEL).COND.SE PRODUCEN DOS ESPERAS PARA LA MISMA CONSULTA SUPERIORES A 30 SEGUNDOS.": "subgrupo_C5_6",
    "C5. LLAMADA EN ESPERA (TÚNEL).OBS": "subgrupo_C5_7",
    "C6. TOMA DE CONTACTO": "C6",
    "C6. TOMA DE CONTACTO.COND.EL ASESOR SE IDENTIFICA CON SU NOMBRE, CON UNA VELOCIDAD DE DISCURSO Y ELOCUCIÓN ADECUADAS.": "subgrupo_C6_1",
    "C6. TOMA DE CONTACTO.COND.EL ASESOR MANTIENE UNA VELOCIDAD Y ELOCUCIÓN ADECUADAS, PERO NO SE IDENTIFICA CON SU NOMBRE.": "subgrupo_C6_2",
    "C6. TOMA DE CONTACTO.COND.EL ASESOR SE IDENTIFICA CON SU NOMBRE, PERO CON UNA VELOCIDAD Y ELOCUCIÓN POCO ADECUADAS.": "subgrupo_C6_3",
    "C6. TOMA DE CONTACTO.COND.EL ASESOR NI SE IDENTIFICA CON SU NOMBRE NI SU VELOCIDAD Y ELOCUCIÓN ES BUENA.": "subgrupo_C6_4",
    "C6. TOMA DE CONTACTO.OBS": "subgrupo_C6_5",
    "C7. IDENTIFICACIÓN": "C7",
    "C7. IDENTIFICACIÓN.COND.LA GRABACIÓN IVR SÍ IDENTIFICA A LA EMPRESA CON SU NOMBRE.": "subgrupo_C7_1",
    "C7. IDENTIFICACIÓN.COND.LA GRABACIÓN IVR NO IDENTIFICA A LA EMPRESA CON SU NOMBRE.": "subgrupo_C7_2",
    "C7. IDENTIFICACIÓN.OBS": "subgrupo_C7_3",
    "C8. PERSONALIZACIÓN": "C8",
    "C8. PERSONALIZACIÓN.COND.EL ASESOR PERSONALIZA LA CONVERSACIÓN CON EL NOMBRE DEL CLIENTE.": "subgrupo_C8_1",
    "C8. PERSONALIZACIÓN.COND.EL ASESOR VUELVE A PEDIR EL NOMBRE DEL CLIENTE CUANDO LO SABE Y LO HA UTILIZADO ANTES.": "subgrupo_C8_2",
    "C8. PERSONALIZACIÓN.COND.EL ASESOR SE EQUIVOCA CON EL NOMBRE DEL CLIENTE.": "subgrupo_C8_3",
    "C8. PERSONALIZACIÓN.COND.EL ASESOR NO PERSONALIZA LA CONVERSACIÓN EN NINGÚN MOMENTO DE ESTA.": "subgrupo_C8_4",
    "C8. PERSONALIZACIÓN.OBS": "subgrupo_C8_5",
    "C9. MOTIVO DE CONTACTO": "C9",
    "C9. MOTIVO DE CONTACTO.COND.EL ASESOR REALIZA EL SONDEO NECESARIO PARA IDENTIFICAR LA NECESIDAD DEL CLIENTE.": "subgrupo_C9_1",
    "C9. MOTIVO DE CONTACTO.COND.EL ASESOR NO REALIZA EL SONDEO NECESARIO PARA IDENTIFICAR LA NECESIDAD DEL CLIENTE.": "subgrupo_C9_2",
    "C9. MOTIVO DE CONTACTO.OBS": "subgrupo_C9_3",
    "C10. REFORMULACIÓN": "C10",
    "C10. REFORMULACIÓN.COND.EL ASESOR UTILIZA LA CONSULTA DEL CLIENTE PARA RESPONDER A ELLA.": "subgrupo_C10_1",
    "C10. REFORMULACIÓN.COND.EL ASESOR REFORMULA LA CONSULTA DEL CLIENTE PARA RESPONDER A ELLA.": "subgrupo_C10_2",
    "C10. REFORMULACIÓN.COND.EL ASESOR RESPONDE DIRECTAMENTE A LA PETICIÓN SIN HABER UTILIZADO LA CONSULTA DEL CLIENTE.": "subgrupo_C10_3",
    "C10. REFORMULACIÓN.COND.EL ASESOR RESPONDE DIRECTAMENTE A LA PETICIÓN SIN HABER REFORMULADO LA CONSULTA DEL CLIENTE.": "subgrupo_C10_4",
    "C10. REFORMULACIÓN.OBS": "subgrupo_C10_5",
    "C11. DIRECCIÓN DE LA LLAMADA": "C11",
    "C11. DIRECCIÓN DE LA LLAMADA.COND.DIRIGE LA SECUENCIA DE LLAMADA MANTENIENDO EL ENFOQUE.": "subgrupo_C11_1",
    "C11. DIRECCIÓN DE LA LLAMADA.COND.NO ALARGA NI PRECIPITA DE MANERA INNECESARIA EL CIERRE DE CONVERSACIÓN.": "subgrupo_C11_2",
    "C11. DIRECCIÓN DE LA LLAMADA.COND.NO DIRIGE LA SECUENCIA DE LLAMADA MANTENIENDO EL ENFOQUE.": "subgrupo_C11_3",
    "C11. DIRECCIÓN DE LA LLAMADA.COND.ALARGA O PRECIPITA DE MANERA INNECESARIA EL CIERRE DE CONVERSACIÓN.": "subgrupo_C11_4",
    "C11. DIRECCIÓN DE LA LLAMADA.OBS": "subgrupo_C11_5",
    "C12. TRANSFERENCIA SIN FRICCIÓN": "C12",
    "C12. TRANSFERENCIA SIN FRICCIÓN.COND.EL CLIENTE NO TIENE QUE VOLVER A EXPLICAR LA CONSULTA AL ASESOR AL QUE SE HA TRANSFERIDO.": "subgrupo_C12_1",
    "C12. TRANSFERENCIA SIN FRICCIÓN.COND.EL CLIENTE EXPLICA PARCIALMENTE LA CONSULTA AL ASESOR AL QUE SE HA TRANSFERIDO.": "subgrupo_C12_2",
    "C12. TRANSFERENCIA SIN FRICCIÓN.COND.EL CLIENTE TIENE QUE VOLVER A EXPLICAR DE NUEVO LA CONSULTA AL ASESOR AL QUE SE HA TRANSFERIDO.": "subgrupo_C12_3",
    "C12. TRANSFERENCIA SIN FRICCIÓN.OBS": "subgrupo_C12_4",
    "C13. SABER ORIENTAR": "C13",
    "C13. SABER ORIENTAR.COND.EL PRIMER ASESOR CONSIGUE TRANSFERIR LA LLAMADA DEL CLIENTE AL ASESOR ADECUADO A LA PRIMERA.": "subgrupo_C13_1",
    "C13. SABER ORIENTAR.COND.EL PRIMER ASESOR NO CONSIGUE TRANSFERIR LA LLAMADA DEL CLIENTE AL ASESOR ADECUADO A LA PRIMERA, TENIENDO QUE VOLVER A TRANSFERIR LA LLAMADA.": "subgrupo_C13_2",
    "C13. SABER ORIENTAR.OBS": "subgrupo_C13_3",
    "C14. SABER ESCUCHAR/ESCUCHA ACTIVA": "C14",
    "C14. SABER ESCUCHAR/ESCUCHA ACTIVA.COND.EL ASESOR NO HA INTERRUMPIDO AL CLIENTE EN NINGÚN MOMENTO DE LA LLAMADA.": "subgrupo_C14_1",
    "C14. SABER ESCUCHAR/ESCUCHA ACTIVA.COND.EL ASESOR HA INTERRUMPIDO AL CLIENTE EN ALGÚN MOMENTO DE LA LLAMADA, PERO SE HA DISCULPADO POR ELLO.": "subgrupo_C14_2",
    "C14. SABER ESCUCHAR/ESCUCHA ACTIVA.COND.EL ASESOR INTERRUMPE AL CLIENTE EN DIFERENTES MOMENTOS DE LA LLAMADA, SIN DISCULPARSE POR ELLO.": "subgrupo_C14_3",
    "C14. SABER ESCUCHAR/ESCUCHA ACTIVA.OBS": "subgrupo_C14_4",
    "C15. SABER DECIR (CAPACIDAD EXPRESIÓN)": "C15",
    "C15. SABER DECIR (CAPACIDAD EXPRESIÓN).COND.EL ASESOR UTILIZA UN DISCURSO ADAPTADO A LA CONSULTA DEL CLIENTE, SIN TÉRMINOS INCOMPRENSIBLES.": "subgrupo_C15_1",
    "C15. SABER DECIR (CAPACIDAD EXPRESIÓN).COND.EL ASESOR UTILIZA EN SU DISCURSO ALGUNOS TECNICISMOS O PALABRAS CLAVE, LAS CUÁLES NO EXPLICA SU SIGNIFICADO PARA FACILITAR LA COMPRENSIÓN DEL CLIENTE.": "subgrupo_C15_2",
    "C15. SABER DECIR (CAPACIDAD EXPRESIÓN).COND.EL ASESOR UTILIZA UN DISCURSO PLAGADO DE TECNICISMOS Y SIGLAS INCOMPRENSIBLES, POCO ENTENDIBLES PARA EL CLIENTE.": "subgrupo_C15_3",
    "C15. SABER DECIR (CAPACIDAD EXPRESIÓN).OBS": "subgrupo_C15_4",
    "C16. CALIDAD DEL TONO": "C16",
    "C16. CALIDAD DEL TONO.COND.EL ASESOR MANTIENE UN TONO Y DISCURSO ADECUADO DURANTE TODA LA LLAMADA.": "subgrupo_C16_1",
    "C16. CALIDAD DEL TONO.COND.DISCURSO ROBOTIZADO.": "subgrupo_C16_2",
    "C16. CALIDAD DEL TONO.COND.EL ASESOR ATIENDE CON PRISA, PROCURA FINALIZAR LA LLAMADA.": "subgrupo_C16_3",
    "C16. CALIDAD DEL TONO.COND.TONO FRIO Y DISTANTE. AUSENCIA DE CONTACTO EMOCIONAL.": "subgrupo_C16_4",
    "C16. CALIDAD DEL TONO.COND.EN ALGÚN MOMENTO DE LA LLAMADA NO SE ENTIENDE AL ASESOR.": "subgrupo_C16_5",
    "C16. CALIDAD DEL TONO.COND.EL ASESOR UTILIZA IRONÍA O SARCASMO.": "subgrupo_C16_6",
    "C16. CALIDAD DEL TONO.COND.EL ASESOR SE MUESTRA POCO CORDIAL AUNQUE EDUCADO.": "subgrupo_C16_7",
    "C16. CALIDAD DEL TONO.COND.EL ASESOR NO ENTREGA RESPUESTA. DEMASIADO INSISTENTE EN LLAMAR EN UN MOMENTO POSTERIOR.": "subgrupo_C16_8",
    "C16. CALIDAD DEL TONO.COND.A PESAR QUE LA ATENCIÓN ES CORRECTA Y SE RESUELVE LA CONSULTA, EL ASESOR TRANSMITE POCO DINAMISMO EN LA LLAMADA. TONO MONÓTONO.": "subgrupo_C16_9",
    "C16. CALIDAD DEL TONO.COND.TONO POCO AMABLE, NADA EMPÁTICO CON EL CLIENTE.": "subgrupo_C16_10",
    "C16. CALIDAD DEL TONO.OBS": "subgrupo_C16_11",
    "C17. IMPRESIÓN GENERAL": "C17",
    "C17. IMPRESIÓN GENERAL.COND.EL ASESOR DEMUESTRA SEGURIDAD DURANTE LA LLAMADA, OFRECIENDO EXPLICACIONES CLARAS.": "subgrupo_C17_1",
    "C17. IMPRESIÓN GENERAL.COND.EL ASESOR DEMUESTRA EDUCACIÓN AL ATENDER LA LLAMADA CON AMABILIDAD Y CORDIALIDAD.": "subgrupo_C17_2",
    "C17. IMPRESIÓN GENERAL.COND.EL ASESOR NO DEMUESTRA SEGURIDAD DURANTE LA LLAMADA, DUDANDO O TITUBEANDO EN DIFERENTES MOMENTOS DE ESTA.": "subgrupo_C17_3",
    "C17. IMPRESIÓN GENERAL.COND.EL ASESOR NO DEMUESTRA EDUCACIÓN AL ATENDER LA LLAMADA CON POCA AMABILIDAD.": "subgrupo_C17_4",
    "C17. IMPRESIÓN GENERAL.COND.LA LLAMADA NO HA SIDO ATENDIDA TRAS PASARSE EL PLAZO DE 4 MINUTOS DE ESPERA Y NO SER ATENDIDOS POR UN ASESOR.": "subgrupo_C17_5",
    "C17. IMPRESIÓN GENERAL.OBS": "subgrupo_C17_6",
    "C18. CALIDAD DEL ENTORNO": "C18",
    "C18. CALIDAD DEL ENTORNO.COND.NO SE DETECTAN INTERFERENCIAS O MICROCORTES DURANTE EL TRANSCURSO DE LA CONVERSACIÓN.": "subgrupo_C18_1",
    "C18. CALIDAD DEL ENTORNO.COND.NO SE DETECTA RUIDO AMBIENTAL DURANTE EL TRANSCURSO DE LA CONVERSACIÓN.": "subgrupo_C18_2",
    "C18. CALIDAD DEL ENTORNO.COND.SE DETECTAN INTERFERENCIAS O MICROCORTES DURANTE EL TRANSCURSO DE LA CONVERSACIÓN.": "subgrupo_C18_3",
    "C18. CALIDAD DEL ENTORNO.COND.SE DETECTA RUIDO AMBIENTAL DURANTE EL TRANSCURSO DE LA CONVERSACIÓN.": "subgrupo_C18_4",
    "C18. CALIDAD DEL ENTORNO.OBS": "subgrupo_C18_5",
    "C19. CALIDAD DE LA RESPUESTA": "C19",
    "C19. CALIDAD DE LA RESPUESTA.COND.EL ASESOR OFRECE UNA RESPUESTA ADECUADA A LA CONSULTA DEL CLIENTE. MUESTRA CONOCIMIENTO (ENTENDIMIENTO) DE LA CONSULTA O PRODUCTO.": "subgrupo_C19_1",
    "C19. CALIDAD DE LA RESPUESTA.COND.EL ASESOR OFRECE UNA RESPUESTA ORIENTATIVA, Y SE INDICA QUE LLAME A OTRO NÚMERO/SUCURSAL/WEB PARA TENER LA INFORMACIÓN. MUESTRA CONOCIMIENTO NO ASENTADO (ENTENDIMIENTO) DE LA CONSULTA O PRODUCTO.": "subgrupo_C19_2",
    "C19. CALIDAD DE LA RESPUESTA.COND.EL ASESOR ENVÍA LA RESPUESTA POR CORREO. EN OTRAS OCASIONES SE HA RESPONDIDO A LA CONSULTA DIRECTAMENTE, SIN NECESIDAD DE OBTENERLA POR OTRA VÍA.": "subgrupo_C19_3",
    "C19. CALIDAD DE LA RESPUESTA.COND.EL ASESOR NO OFRECE UNA RESPUESTA COMPLETA. EN OTRAS OCASIONES SE HA OFRECIDO UNA INFORMACIÓN COMPLETA. NO APORTA INFORMACIÓN NECESARIA PARA QUE EL CLIENTE LO ENTIENDA PERFECTAMENTE.": "subgrupo_C19_4",
    "C19. CALIDAD DE LA RESPUESTA.COND.NO SE OFRECE UNA RESPUESTA COMPLETA, SINO QUE SE REQUIERE QUE DEMOS NUESTROS DATOS. EN OTRAS OCASIONES SE HA OFRECIDO UNA INFORMACIÓN SIN REQUERIR APORTAR DATOS.": "subgrupo_C19_5",
    "C19. CALIDAD DE LA RESPUESTA.COND.EL ASESOR NO SE CENTRA EN OFRECER LA RESPUESTA SOLICITADA POR EL CLIENTE. APORTA INFORMACIÓN POCO INFLUYENTE PARA LA CONSULTA.": "subgrupo_C19_6",
    "C19. CALIDAD DE LA RESPUESTA.COND.LA RESPUESTA NO ES COMPLETA, AL INTENTAR TRANSFERIR EL ASESOR LA LLAMADA AL DEPARTAMENTO CORRESPONDIENTE SIN ÉXITO AL ESTAR FUERA DEL HORARIO DE ATENCIÓN.": "subgrupo_C19_7",
    "C19. CALIDAD DE LA RESPUESTA.COND.LA RESPUESTA NO ES COMPLETA, AL INTENTAR EL ASESOR CONSEGUIR LA INFORMACIÓN POR OTRA VÍA Y NO CONSEGUIRLO (NO LE COGEN EL TELÉFONO, LA LÍNEA ESTÁ OCUPADA O ALGUIEN ESTÁ OCUPADO PARA HACER LA CONSULTA).": "subgrupo_C19_8",
    "C19. CALIDAD DE LA RESPUESTA.COND.LA RESPUESTA ES ESCUETA. CONTESTA CON MONOSÍLABOS: NO EXPLICA NI DA OPCIONES A LA PREGUNTA SOLICITADA.": "subgrupo_C19_9",
    "C19. CALIDAD DE LA RESPUESTA.COND.RESPUESTA NO ADECUADA, DIFERENTE A LA CONSULTA. FALTA DE ESCUCHA ACTIVA. O FALTA DE CONOCIMIENTO (ENTENDIMIENTO) DE LA CONSULTA O PRODUCTO.": "subgrupo_C19_10",
    "C19. CALIDAD DE LA RESPUESTA.COND.EL ASESOR NO OFRECE UNA RESPUESTA, SINO QUE SE INDICA OTRO NÚMERO AL QUE LLAMAR/MAIL QUE ENVIAR/WEB QUE VISITAR/RED SOCIAL A CONSULTAR/CHAT AL QUE HABLAR.": "subgrupo_C19_11",
    "C19. CALIDAD DE LA RESPUESTA.COND.LA LLAMADA NO HA SIDO ATENDIDA TRAS PASARSE EL PLAZO DE 4 MINUTOS DE ESPERA Y NO SER ATENDIDOS POR UN ASESOR.": "subgrupo_C19_12",
    "C19. CALIDAD DE LA RESPUESTA.OBS": "subgrupo_C19_13",
    "C20. PROACTIVIDAD": "C20",
    "C20. PROACTIVIDAD.COND.INFORMACIÓN ÚTIL, QUE APORTA VALOR AL CLIENTE.": "subgrupo_C20_1",
    "C20. PROACTIVIDAD.COND.ADAPTA LOS PROCESOS EN LA MEDIDA DE LO POSIBLE Y OFRECE ALTERNATIVAS.": "subgrupo_C20_2",
    "C20. PROACTIVIDAD.COND.TOMA DECISIONES EFICIENTES Y EFICACES PARA RESOLVER LA LLAMADA.": "subgrupo_C20_3",
    "C20. PROACTIVIDAD.COND.EXCESO DE INFORMACIÓN NO ÚTIL, QUE NO APORTA VALOR AL CLIENTE.": "subgrupo_C20_4",
    "C20. PROACTIVIDAD.COND.NO ADAPTA LOS PROCESOS EN LA MEDIDA DE LO POSIBLE Y SÓLO OFRECE ALTERNATIVAS POR INSISTENCIA DEL CLIENTE.": "subgrupo_C20_5",
    "C20. PROACTIVIDAD.COND.NO TOMA DECISIONES EFICIENTES Y EFICACES PARA RESOLVER LA LLAMADA.": "subgrupo_C20_6",
    "C20. PROACTIVIDAD.OBS": "subgrupo_C20_7",
    "C21. SOLUCIÓN AL PRIMER CONTACTO (FCR)": "C21",
    "C21. SOLUCIÓN AL PRIMER CONTACTO (FCR).COND.SE SOLUCIONA LA CONSULTA EN EL PRIMER CONTACTO Y NO ES NECESARIO REALIZAR UN CONTACTO POSTERIOR.": "subgrupo_C21_1",
    "C21. SOLUCIÓN AL PRIMER CONTACTO (FCR).COND.NO SE SOLUCIONA LA CONSULTA EN EL PRIMER CONTACTO Y ES NECESARIO REALIZAR UN CONTACTO POSTERIOR.": "subgrupo_C21_2",
    "C21. SOLUCIÓN AL PRIMER CONTACTO (FCR).OBS": "subgrupo_C21_3",
    "C22. IMAGEN CORPORATIVA": "C22",
    "C22. IMAGEN CORPORATIVA.COND.LA PROFESIONALIDAD DEL GESTOR TRASLADA UNA IMAGEN POSITIVA.": "subgrupo_C22_1",
    "C22. IMAGEN CORPORATIVA.COND.SE DISCULPA ANTE LAS MOLESTIAS EVIDENCIADAS POR EL CLIENTE DURANTE LA LLAMADA.": "subgrupo_C22_2",
    "C22. IMAGEN CORPORATIVA.COND.LA FALTA DE PROFESIONALIDAD DEL GESTOR TRASLADA UNA IMAGEN NEGATIVA.": "subgrupo_C22_3",
    "C22. IMAGEN CORPORATIVA.COND.NO SE DISCULPA ANTE LAS MOLESTIAS EVIDENCIADAS POR EL CLIENTE DURANTE LA LLAMADA.": "subgrupo_C22_4",
    "C22. IMAGEN CORPORATIVA.OBS": "subgrupo_C22_5",
    "C23. DESPEDIDA": "C23",
    "C23. DESPEDIDA.COND.EL ASESOR SE DESPIDE DEL CLIENTE CON SU NOMBRE, HABIÉNDOSE ASEGURADO DE QUE TODAS SUS DUDAS ESTÉN RESUELTAS.": "subgrupo_C23_1",
    "C23. DESPEDIDA.COND.EL ASESOR SE DESPIDE DEL CLIENTE CON SU NOMBRE, PERO NO SE ASEGURA QUE LE QUEDEN DUDAS POR RESOLVER.": "subgrupo_C23_2",
    "C23. DESPEDIDA.COND.EL ASESOR SE ASEGURA QUE TODAS LAS DUDAS DEL CLIENTE ESTÉN RESUELTAS, PERO NO UTILIZA EL NOMBRE DE ESTE EN LA DESPEDIDA.": "subgrupo_C23_3",
    "C23. DESPEDIDA.COND.EL ASESOR NI SE DESPIDE DEL CLIENTE CON SU NOMBRE NI SE ASEGURA QUE LE QUEDEN DUDAS POR RESOLVER.": "subgrupo_C23_4",
    "C23. DESPEDIDA.COND.NO HA HABIDO DESPEDIDA AL NO HABERSE TRANSFERIDO LA LLAMADA.": "subgrupo_C23_5",
    "C23. DESPEDIDA.COND.NO HA HABIDO DESPEDIDA AL CORTARSE LA TRANSFERENCIA.": "subgrupo_C23_6",
    "C23. DESPEDIDA.OBS": "subgrupo_C23_7"
}

# Filtrar solo las columnas que están en el diccionario
columnas_validas = [col for col in df2.columns if col in codigo_a_texto]

# Subset del DataFrame con esas columnas
df2 = df2[columnas_validas]

# Renombrar las columnas según el diccionario
df.rename(columns=codigo_a_texto, inplace=True)

# Mostrar los primeros resultados para verificar
print(df2.columns.tolist())
print(len(df2.columns))

df2.head()

# %%
# Diccionario para almacenar los resultados
resultados = {}

# Columnas principales a analizar
columnas = [f'C{i}' for i in range(1, 20)]  # C1 a C19

# Recorremos todas las columnas
for columna in columnas:
    if columna in df2.columns:
        # Buscar subgrupos relacionados con esta columna
        subgrupos = [col for col in df2.columns if col.startswith(f'subgrupo_{columna}')]

        for subgrupo in subgrupos:
            # Filtrar solo filas donde la variable principal es 0 o 1
            filas_validas = df2[(df2[columna] == 0) | (df2[columna] == 1)]

            # Contar los 1 en el subgrupo
            cuenta_1 = (filas_validas[subgrupo] == 1).sum()

            # Guardar el resultado (una única vez por subgrupo)
            resultados[subgrupo] = cuenta_1

# Convertimos directamente el diccionario a un DataFrame
resultados_df2 = pd.DataFrame(list(resultados.items()), columns=['Subgrupo', 'Penalizaciones'])

# Mostramos el DataFrame
print(resultados_df2)
# Out:
#          Subgrupo  Penalizaciones
# 0   subgrupo_C1_1               0
# 1   subgrupo_C1_2              97
# 2   subgrupo_C1_3              36
# 3   subgrupo_C1_4              17
# 4   subgrupo_C1_5              10
# ..            ...             ...
# 85  subgrupo_C9_2               0
# 86  subgrupo_C9_3               0
# 87  subgrupo_C9_4               0
# 88  subgrupo_C9_5               0
# 89  subgrupo_C9_6               0
#
# [90 rows x 2 columns]

# %%
# Guardamos el DataFrame 'resultados_df' con los nombres reales en un archivo Excel
output_path = '/content/resultados_df_mail.xlsx'
resultados_df2.to_excel(output_path, index=False)

# Descargar el archivo generado
from google.colab import files
files.download(output_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-acf70f33adf0> in <cell line: 0>()
#       1 # Guardamos el DataFrame 'resultados_df' con los nombres reales en un archivo Excel
#       2 output_path = '/content/resultados_df_mail.xlsx'
# ----> 3 resultados_df2.to_excel(output_path, index=False)
#       4
#       5 # Descargar el archivo generado
#
# NameError: name 'resultados_df2' is not defined

# %% [markdown]
# **MAIL obtener penalizaciones de columna con puntuación máxima de 4**

# %%
subgrupos_c16 = [col for col in df2.columns if col.startswith('subgrupo_C16')]

penalizaciones_c16 = {}

if 'C16' in df2.columns:
    filas_c16 = df2[(df2['C16'] == 0) | (df2['C16'] == 2)]

    for subgrupo in subgrupos_c16:
        cuenta = (filas_c16[subgrupo] == 1).sum()
        penalizaciones_c16[subgrupo] = cuenta

penalizaciones_c16_mail = pd.DataFrame(
    list(penalizaciones_c16.items()),
    columns=['Subgrupo_C16', 'Penalizaciones_C16']
)

print(penalizaciones_c16_mail)
# Out:
#      Subgrupo_C16  Penalizaciones_C16
# 0  subgrupo_C16_1                   0
# 1  subgrupo_C16_2                   0
# 2  subgrupo_C16_3                   3
# 3  subgrupo_C16_4                   2
# 4  subgrupo_C16_5                   0
# 5  subgrupo_C16_6                   0
# 6  subgrupo_C16_7                  17
# 7  subgrupo_C16_8                   0

# %%
# Guardamos el DataFrame 'resultados_df' con los nombres reales en un archivo Excel
output_path = '/content/resultados_df_chatweb.xlsx'
penalizaciones_c16_mail.to_excel(output_path, index=False)

# Descargar el archivo generado
from google.colab import files
files.download(output_path)

# %% [markdown]
# # **Ejecutar solo para CHATS WEB**

# %%
import pandas as pd

# Ruta del archivo Excel en tu Google Drive
file_path = '/content/drive/MyDrive/Sottotempo/ChatWeb.xlsx'

# Cargar el archivo Excel
df3 = pd.read_excel(file_path)

df3.head()
# Out:
#    C1  subgrupo_C1_1 subgrupo_C1_2 subgrupo_C1_3 subgrupo_C1_4  C2  \
# 0   2              1                                             1
# 1   2              1                                             2
# 2   2              1                                             1
# 3   2              1                                             2
# 4   2              1                                             2
#
#   subgrupo_C2_1 subgrupo_C2_2 subgrupo_C2_3 subgrupo_C2_4  ... C16  \
# 0                           1                              ...   2
# 1             1                                            ...   2
# 2                           1                              ...   2
# 3             1                                            ...   0
# 4             1                                            ...   2
#
#   subgrupo_C16_1  subgrupo_C16_2  subgrupo_C16_3 subgrupo_C16_4  \
# 0              0               1
# 1              0               1
# ...

# %%
# Diccionario para almacenar los resultados
resultados = {}

# Columnas principales a analizar
columnas = [f'C{i}' for i in range(1, 18)]  # C1 a C18

# Recorremos todas las columnas
for columna in columnas:
    if columna in df3.columns:
        # Buscar subgrupos relacionados con esta columna
        subgrupos = [col for col in df3.columns if col.startswith(f'subgrupo_{columna}')]

        for subgrupo in subgrupos:
            # Filtrar solo filas donde la variable principal es 0 o 1
            filas_validas = df3[(df3[columna] == 0) | (df3[columna] == 1)]

            # Contar los 1 en el subgrupo
            cuenta_1 = (filas_validas[subgrupo] == 1).sum()

            # Guardar el resultado (una única vez por subgrupo)
            resultados[subgrupo] = cuenta_1

# Convertimos directamente el diccionario a un DataFrame
resultados_df3 = pd.DataFrame(list(resultados.items()), columns=['Subgrupo', 'Penalizaciones'])

# Mostramos el DataFrame
print(resultados_df3)
# Out:
#           Subgrupo  Penalizaciones
# 0    subgrupo_C1_1               0
# 1    subgrupo_C1_2               0
# 2    subgrupo_C1_3               0
# 3    subgrupo_C1_4               0
# 4   subgrupo_C10_1               0
# ..             ...             ...
# 74   subgrupo_C8_3               0
# 75   subgrupo_C8_4               0
# 76   subgrupo_C9_1               0
# 77   subgrupo_C9_2               6
# 78   subgrupo_C9_3               0
#
# [79 rows x 2 columns]

# %%
# Guardamos el DataFrame 'resultados_df' con los nombres reales en un archivo Excel
output_path = '/content/resultados_df_chatweb.xlsx'
resultados_df3.to_excel(output_path, index=False)

# Descargar el archivo generado
from google.colab import files
files.download(output_path)

# %% [markdown]
# **CHATWEB obtener penalizaciones de columna con puntuación máxima de 4**

# %%
subgrupos_c13 = [col for col in df3.columns if col.startswith('subgrupo_C13')]

penalizaciones_c13_0_2 = {}

if 'C13' in df3.columns:
    filas_c13_0_2 = df3[(df3['C13'] == 0) | (df3['C13'] == 2)]

    for subgrupo in subgrupos_c13:
        cuenta = (filas_c13_0_2[subgrupo] == 1).sum()
        penalizaciones_c13_0_2[subgrupo] = cuenta

penalizaciones_c13_chat = pd.DataFrame(
    list(penalizaciones_c13_0_2.items()),
    columns=['Subgrupo_C13', 'Penalizaciones_C13_0_2']
)

print(penalizaciones_c13_chat)
# Out:
#      Subgrupo_C13  Penalizaciones_C13_0_2
# 0  subgrupo_C13_1                       0
# 1  subgrupo_C13_2                       0
# 2  subgrupo_C13_3                       0
# 3  subgrupo_C13_4                       0
# 4  subgrupo_C13_5                       0
# 5  subgrupo_C13_6                       0
# 6  subgrupo_C13_7                       0

# %%
# Guardamos el DataFrame 'resultados_df' con los nombres reales en un archivo Excel
output_path = '/content/resultados_df_wappC13.xlsx'
penalizaciones_c13_chat.to_excel(output_path, index=False)

# Descargar el archivo generado
from google.colab import files
files.download(output_path)

# %% [markdown]
# # **Ejecutar solo para WHATSAPP**

# %%
import pandas as pd

# Ruta del archivo Excel en tu Google Drive
file_path = '/content/drive/MyDrive/Sottotempo/Wsapp.xlsx'

# Cargar el archivo Excel
df4 = pd.read_excel(file_path)

df4.head()
# Out:
#    C1  subgrupo_C1_1 subgrupo_C1_2 subgrupo_C1_3 subgrupo_C1_4  C2  \
# 0   2              1                                             0
# 1   2              1                                             2
# 2   2              1                                             2
# 3   2              1                                             0
# 4   2              1                                             0
#
#   subgrupo_C2_1 subgrupo_C2_2 subgrupo_C2_3 subgrupo_C2_4  ... subgrupo_C14_3  \
# 0                                         1             0  ...
# 1             1                                            ...
# 2             1                                            ...
# 3                                         1             0  ...
# 4                                         1             0  ...
#
#    subgrupo_C14_4 C15 subgrupo_C15_1 subgrupo_C15_2 subgrupo_C15_3 C16  \
# 0                                                                    2
# ...

# %%
# Diccionario para almacenar los resultados
resultados = {}

# Columnas principales a analizar
columnas = [f'C{i}' for i in range(1, 17)]  # C1 a C17

# Recorremos todas las columnas
for columna in columnas:
    if columna in df4.columns:
        # Buscar subgrupos relacionados con esta columna
        subgrupos = [col for col in df4.columns if col.startswith(f'subgrupo_{columna}')]

        for subgrupo in subgrupos:
            # Filtrar solo filas donde la variable principal es 0 o 1
            filas_validas = df4[(df4[columna] == 0) | (df4[columna] == 1)]

            # Contar los 1 en el subgrupo
            cuenta_1 = (filas_validas[subgrupo] == 1).sum()

            # Guardar el resultado (una única vez por subgrupo)
            resultados[subgrupo] = cuenta_1

# Convertimos directamente el diccionario a un DataFrame
resultados_df4 = pd.DataFrame(list(resultados.items()), columns=['Subgrupo', 'Penalizaciones'])

# Mostramos el DataFrame
print(resultados_df4)
# Out:
#           Subgrupo  Penalizaciones
# 0    subgrupo_C1_1               0
# 1    subgrupo_C1_2               0
# 2    subgrupo_C1_3               0
# 3    subgrupo_C1_4               0
# 4   subgrupo_C10_1               0
# ..             ...             ...
# 62   subgrupo_C9_4               0
# 63   subgrupo_C9_5               0
# 64   subgrupo_C9_6               0
# 65   subgrupo_C9_7               0
# 66   subgrupo_C9_8               0
#
# [67 rows x 2 columns]

# %%
# Guardamos el DataFrame 'resultados_df' con los nombres reales en un archivo Excel
output_path = '/content/resultados_df_wapp.xlsx'
resultados_df4.to_excel(output_path, index=False)

# Descargar el archivo generado
from google.colab import files
files.download(output_path)

# %% [markdown]
# **WAPP obtener penalizaciones de columna con puntuación máxima de 4**

# %%
subgrupos_c13 = [col for col in df4.columns if col.startswith('subgrupo_C13')]

penalizaciones_c13_0_2 = {}

if 'C13' in df4.columns:
    filas_c13_0_2 = df4[(df4['C13'] == 0) | (df4['C13'] == 2)]

    for subgrupo in subgrupos_c13:
        cuenta = (filas_c13_0_2[subgrupo] == 1).sum()
        penalizaciones_c13_0_2[subgrupo] = cuenta

penalizaciones_c13_df = pd.DataFrame(
    list(penalizaciones_c13_0_2.items()),
    columns=['Subgrupo_C13', 'Penalizaciones_C13_0_2']
)

print(penalizaciones_c13_df)
# Out:
#      Subgrupo_C13  Penalizaciones_C13_0_2
# 0  subgrupo_C13_1                       1
# 1  subgrupo_C13_2                       0
# 2  subgrupo_C13_3                       0
# 3  subgrupo_C13_4                       0
# 4  subgrupo_C13_5                       0
# 5  subgrupo_C13_6                       0
# 6  subgrupo_C13_7                       0

# %%
# Guardamos el DataFrame 'resultados_df' con los nombres reales en un archivo Excel
output_path = '/content/resultados_df_wappC13.xlsx'
penalizaciones_c13_df.to_excel(output_path, index=False)

# Descargar el archivo generado
from google.colab import files
files.download(output_path)
